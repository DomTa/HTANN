# %%
import json

# Charger le fichier DataSources.json
with open('DataSources.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Afficher le type et le contenu
print("Type de data :", type(data))
print("Contenu de data :")
print(json.dumps(data, indent=2, ensure_ascii=False)[:1000])  # Affiche les 1000 premiers caractères
# Out:
# Type de data : <class 'dict'>
# Contenu de data :
# {
#   "DataSources": [
#     {
#       "Type": "ServiceInfo",
#       "Name": "Utilisateursd’Office365",
#       "ServiceKind": "ConnectedWadl",
#       "WadlMetadata": {
#         "WadlXml": "<application xmlns:xml=\"http://www.w3.org/XML/1998/namespace\" xmlns:xs=\"http://www.w3.org/2001/XMLSchema\" xmlns:service=\"https://europe-002.azure-apim.net/apim/office365users\" xmlns:siena=\"http://schemas.microsoft.com/MicrosoftProjectSiena/WADL/2014/11\" siena:serviceId=\"Utilisateursd’Office365\" xmlns=\"http://wadl.dev.java.net/2009/02\"><doc title=\"Utilisateurs d’Office 365\">Le fournisseur de connexion Utilisateurs d’Office 365 vous permet d’accéder aux profils d’utilisateurs de votre organisation à l’aide de votre compte Office 365. Vous pouvez effectuer différentes actions, notamment obtenir votre profil, celui d’un utilisateur ou celui d’un responsable, obtenir des rapports directs, ou encore modifier un profil d’utilisateur.</doc><grammars><jsonTypes targetNamespace=\"https://europe-002.azure-a

# %%
import json
from collections import defaultdict

# Charger le fichier DataSources.json
with open('DataSources.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Accéder à la liste des DataSources
data_sources = data["DataSources"]

# Tables à exclure
excluded_tables = ["Divisions", "Utilisateurs"]

# Colonnes systèmes à exclure
excluded_columns = {
    "utcconversiontimezonecode", "_ownerid_value", "statuscode", "statecode",
    "modifiedonbehalfby", "createdonbehalfby", "owninguser", "timezoneruleversionnumber",
    "owningbusinessunit", "modifiedon", "modifiedby", "versionnumber",
    "overriddencreatedon", "createdby", "importsequencenumber", "owningteam", "createdon"
}

# Dictionnaire pour stocker les tables et leurs colonnes
tables = {}

# Dictionnaire pour les Option Sets
option_sets = {}
option_sets_by_column = {}  # Pour lier rapidement colonne -> choix

# Extraire d'abord tous les Option Sets
for ds in data_sources:
    if ds.get("Type") == "OptionSetInfo":
        option_set_name = ds.get("Name")
        related_entity = ds.get("RelatedEntityName")
        related_column = ds.get("RelatedColumnInvariantName")
        option_mapping = ds.get("OptionSetInfoNameMapping", {})
        
        if option_set_name and related_entity and related_column:
            key = f"{related_entity}.{related_column}"
            option_sets_by_column[key] = option_mapping

# Parcourir les DataSources pour les tables
for ds in data_sources:
    if ds.get("Type") == "NativeCDSDataSourceInfo":
        table_name = ds.get("Name") or ds.get("LogicalName") or ds.get("EntitySetName")
        if not table_name or table_name in excluded_tables:
            continue
            
        columns_detail = {}
        name_mapping = ds.get("NativeCDSDataSourceInfoNameMapping", {})
        
        if name_mapping:
            for technical_name, display_name in name_mapping.items():
                if technical_name in excluded_columns:
                    continue
                columns_detail[technical_name] = display_name
        
        tables[table_name] = columns_detail

# Afficher les tables avec leurs colonnes et listes de choix
print("=== LISTE DES TABLES AVEC COLONNES ET LISTES DE CHOIX ===")

for table, cols in tables.items():
    print(f"\nTable: {table} ({len(cols)} colonnes)")
    for tech_name, display_name in sorted(cols.items()):
        print(f"  {tech_name} → {display_name}")
        
        # Vérifier s'il y a une liste de choix pour cette colonne
        option_key = f"{table}.{tech_name}"
        if option_key in option_sets_by_column:
            options = option_sets_by_column[option_key]
            print(f"    📋 Liste de choix ({len(options)} valeurs):")
            for key, value in sorted(options.items()):
                print(f"      {key} → {value}")

# Export vers format MERMAID pour graphique d'architecture

# Fonction pour nettoyer les noms pour Mermaid
def clean_mermaid_name(name):
    # Remplacer les caractères problématiques
    cleaned = re.sub(r'[^a-zA-Z0-9_]', '_', name)
    # S'assurer qu'il ne commence pas par un chiffre
    if cleaned and cleaned[0].isdigit():
        cleaned = "attr_" + cleaned
    return cleaned if cleaned else "unnamed_attr"

# Fonction pour générer le diagramme Mermaid avec la bonne syntaxe
def generate_mermaid_graph(tables):
    mermaid_lines = ["```mermaid", "erDiagram"]
    
    # Ajouter les entités avec la syntaxe correcte
    for table, cols in tables.items():
        clean_table = clean_mermaid_name(table)
        
        mermaid_lines.append(f'    {clean_table} {{')
        
        # Ajouter les attributs (limité à 10 pour la lisibilité)
        for i, (tech_name, display_name) in enumerate(list(cols.items())[:10]):
            clean_attr = clean_mermaid_name(tech_name)
            # Syntaxe correcte : type nom
            mermaid_lines.append(f'        string {clean_attr} "{display_name}"')
        
        if len(cols) > 10:
            mermaid_lines.append(f'        string other "... et {len(cols) - 10} autres colonnes"')
            
        mermaid_lines.append('    }')
    
    # Ajouter quelques relations basiques
    for table, cols in tables.items():
        clean_table = clean_mermaid_name(table)
        for col_name in cols.keys():
            if col_name.endswith('id') and col_name != 'id':
                target_table = col_name[:-2]  # Enlever 'id'
                if target_table in tables:
                    clean_target = clean_mermaid_name(target_table)
                    clean_col = clean_mermaid_name(col_name)
                    mermaid_lines.append(f'    {clean_target} ||--o{{ {clean_table} : "{col_name}"')
    
    mermaid_lines.append("```")
    return "\n".join(mermaid_lines)

# Export vers format JSON structuré
def generate_structured_json():
    architecture = {
        "tables": {},
        "relationships": [],
        "option_sets": {}
    }
    
    # Tables et colonnes
    for table, cols in tables.items():
        architecture["tables"][table] = {
            "columns": cols,
            "option_sets": {}
        }
        
        # Ajouter les option sets pour cette table
        for col_name in cols.keys():
            option_key = f"{table}.{col_name}"
            if option_key in option_sets_by_column:
                architecture["tables"][table]["option_sets"][col_name] = option_sets_by_column[option_key]
    
    # Relations basiques
    for table, cols in tables.items():
        for col_name in cols.keys():
            if col_name.endswith('id') and col_name != 'id':
                target_table = col_name[:-2]
                if target_table in tables:
                    architecture["relationships"].append({
                        "from_table": target_table,
                        "to_table": table,
                        "column": col_name,
                        "type": "lookup"
                    })
    
    return architecture
# Export pour Drawio

import json
import re

def clean_xml_text(text):
    """Nettoyer le texte pour XML"""
    if not text:
        return ""
    return text.replace("&", "&amp;").replace("<", "&lt;").replace(">", "&gt;").replace('"', "&quot;")

def generate_drawio_no_relations(tables, option_sets_by_column):
    xml_lines = [
        '<?xml version="1.0" encoding="UTF-8"?>',
        '<mxfile host="app.diagrams.net">',
        '<diagram name="Architecture Power Apps" id="architecture-powerapps">',
        '<mxGraphModel dx="1426" dy="745" grid="1" gridSize="10" guides="1" tooltips="1" connect="1">'
    ]
    
    xml_lines.append('<root>')
    xml_lines.append('<mxCell id="0"/>')
    xml_lines.append('<mxCell id="1" parent="0"/>')
    
    # Générer les tables avec toutes les colonnes
    x_pos = 20
    y_pos = 20
    table_positions = {}  # Pour usage futur
    
    for i, (table, cols) in enumerate(tables.items()):
        table_id = f"table_{i}"
        table_positions[table] = {
            'id': table_id,
            'x': x_pos + (i % 3) * 300,  # 3 colonnes max
            'y': y_pos + (i // 3) * 400   # Nouvelle ligne tous les 3
        }
        
        # Hauteur calculée selon le nombre de colonnes
        table_height = 50 + min(len(cols) * 26, 600)  # Max 600px
        
        # Table swimlane
        xml_lines.append(f'<mxCell id="{table_id}" value="{clean_xml_text(table)}" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=30;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;swimlaneFillColor=#ffffff;fillColor=#e0f7fa;" vertex="1" parent="1">')
        xml_lines.append(f'  <mxGeometry x="{table_positions[table]["x"]}" y="{table_positions[table]["y"]}" width="280" height="{table_height}" as="geometry"/>')
        xml_lines.append('</mxCell>')
        
        # Ajouter les colonnes
        current_y = 30
        for j, (tech_name, display_name) in enumerate(cols.items()):
            if j >= 60:  # Limite pour éviter les diagrammes trop lourds
                # Ajouter une ligne "et X autres"
                remaining = len(cols) - 60
                if remaining > 0:
                    attr_id = f"{table_id}_attr_remaining"
                    xml_lines.append(f'<mxCell id="{attr_id}" value="... et {remaining} autres colonnes" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=middle;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" vertex="1" parent="{table_id}">')
                    xml_lines.append(f'  <mxGeometry y="{current_y}" width="280" height="26" as="geometry"/>')
                    xml_lines.append('</mxCell>')
                break
                
            attr_id = f"{table_id}_attr_{j}"
            display_text = display_name if display_name else tech_name
            
            # Vérifier s'il y a une liste de choix
            option_key = f"{table}.{tech_name}"
            if option_key in option_sets_by_column:
                options = option_sets_by_column[option_key]
                # Ajouter les valeurs possibles
                option_values = ", ".join(list(options.values())[:3])  # Max 3 valeurs
                if len(options) > 3:
                    option_values += ", ..."
                display_text = f"{display_text} [choix: {option_values}]"
            
            # Style différent pour les colonnes avec listes de choix
            style = "text;strokeColor=none;fillColor=none;align=left;verticalAlign=middle;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;"
            if option_key in option_sets_by_column:
                style = "text;strokeColor=none;fillColor=#fff3e0;align=left;verticalAlign=middle;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;"
            
            xml_lines.append(f'<mxCell id="{attr_id}" value="{clean_xml_text(display_text)}" style="{style}" vertex="1" parent="{table_id}">')
            xml_lines.append(f'  <mxGeometry y="{current_y}" width="280" height="26" as="geometry"/>')
            xml_lines.append('</mxCell>')
            
            current_y += 26
    
    xml_lines.append('</root>')
    xml_lines.append('</mxGraphModel>')
    xml_lines.append('</diagram>')
    xml_lines.append('</mxfile>')
    
    with open('architecture_drawio.xml', 'w', encoding='utf-8') as f:
        f.write('\n'.join(xml_lines))
    
    print("✅ Fichier 'architecture_drawio.xml' généré")
    print("Nombre de tables: ", len(tables))
    total_cols = sum(len(cols) for cols in tables.values())
    print("Nombre total de colonnes: ", total_cols)



# Proposer les exports
print(f"\n=== OPTIONS D'EXPORT ===")
print("1. Mermaid (pour diagramme ER)")
print("2. JSON structuré (complet)")
print("3. CSV des tables et colonnes")
print("4. XML")
print("5. Tous les formats")

choice = input("Quel format voulez-vous générer ? (1/2/3/4/5): ").strip()

if choice in ['1', '5']:
    mermaid_content = generate_mermaid_graph(tables)
    with open('architecture_mermaid.md', 'w', encoding='utf-8') as f:
        f.write("# Architecture des données\n\n")
        f.write(mermaid_content)
    print("✅ Fichier 'architecture_mermaid.md' généré")

if choice in ['2', '5']:
    structured_data = generate_structured_json()
    with open('architecture_complete.json', 'w', encoding='utf-8') as f:
        json.dump(structured_data, f, indent=2, ensure_ascii=False)
    print("✅ Fichier 'architecture_complete.json' généré")

if choice in ['3', '5']:
    with open('tables_colonnes.csv', 'w', encoding='utf-8') as f:
        f.write("Table;Nom Technique;Nom Affiché;Avec Liste de Choix\n")
        for table, cols in tables.items():
            for tech_name, display_name in cols.items():
                has_options = "Oui" if f"{table}.{tech_name}" in option_sets_by_column else "Non"
                f.write(f"{table};{tech_name};{display_name};{has_options}\n")
    print("✅ Fichier 'tables_colonnes.csv' généré")

if choice in ['4', '5']:
    # Utilisation dans ton script principal
    generate_drawio_no_relations(tables, option_sets_by_column)


print("\n🎉 Extraction terminée !")
# Out:
# === LISTE DES TABLES AVEC COLONNES ET LISTES DE CHOIX ===
#
# Table: Cuves (42 colonnes)
#   cr446_ProgAval → ProgAval
#   cr446_affectation_cuve_cr446_cuve → Affectations
#   cr446_affectee → % Affectée
#   cr446_choix1percent → % Choix 1
#   cr446_choix2percent → % Choix 2
#   cr446_choix3percent → % Choix 3
#   cr446_commentaire_Cuve_cr446_cuve → Commentaires
#   cr446_commentairecuve → Commentaire
#   cr446_cqfr_Cuve_cr446_cuve → CQFR
#   cr446_cuve_AsyncOperations → Tâches système
#   cr446_cuve_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_cuve_DuplicateBaseRecord → Enregistrements dupliqués (cr446_cuve_DuplicateBaseRecord)
#   cr446_cuve_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_cuve_DuplicateMatchingRecord)
#   cr446_cuve_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_cuve_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_cuve_ProcessSession → Sessions de traitement
#   cr446_cuve_SyncErrors → Erreurs de synchronisation
#   cr446_cuveid → Cuve
#   cr446_dateetape → Date Etape
#   cr446_defaut_Cuve_cr446_cuve → Défauts
#   cr446_espece → Espèce
#     📋 Liste de choix (5 valeurs):
#       113790000 → Alligator
#       113790001 → Niloticus
#       113790002 → Porosus
#       967350001 → Iguane
#       967350002 → Java
#   cr446_essai_Cuve_cr446_cuve → Essais
#   cr446_etape → Etape
#   cr446_etapetri → EtapeTri
#   cr446_numero → Numéro
#   cr446_poids → Poids
#   cr446_poidstxt → PoidsTxt
#   cr446_priorite → Priorité
#     📋 Liste de choix (5 valeurs):
#       113790000 → Basse
#       113790001 → Moyenne
#       113790002 → Elevée
#       113790003 → Urgente
#       113790004 → Bloquée
#   cr446_programme_Cuve_cr446_cuve → Programmes Amont
#   cr446_qtyaffectee → Qty Affectée
#   cr446_qtychoix1 → Qty Choix 1
#   cr446_qtychoix2 → Qty Choix 2
#   cr446_qtychoix3 → Qty Choix 3
#   cr446_quantite → Quantité
#   cr446_quantitetxt → QuantitéTxt
#   cr446_taille → Taille
#     📋 Liste de choix (9 valeurs):
#       1 → 19-
#       2 → 20-24
#       3 → 25-29
#       4 → 30-34
#       5 → 35-39
#       6 → 40-44
#       7 → 45-49
#       8 → 50-54
#       9 → 55-59
#   cr446_tannage → Tannage
#     📋 Liste de choix (9 valeurs):
#       113790000 → Barolo
#       113790001 → Chantilly
#       113790002 → Classique
#       113790003 → Externe
#       113790004 → Himalaya
#       113790005 → Himalaya SCSB
#       113790006 → Jungle
#       113790007 → Sans Bisphenol
#       113790008 → Sans Chrome
#   smallapp_etat → Etat
#   smallapp_familleespece → Famille Espèce
#     📋 Liste de choix (2 valeurs):
#       579940000 → Crocodile
#       579940001 → Lézard
#   smallapp_foulon → Foulon Rivière
#     📋 Liste de choix (14 valeurs):
#       579940000 → PT1
#       579940001 → PT2
#       579940002 → PT3
#       579940003 → PR1
#       579940004 → PR2
#       579940005 → PR3
#       579940006 → GT1
#       579940007 → GT2
#       579940008 → GT3
#       579940009 → GR1
#       579940010 → GR2
#       967350001 → NA
#       967350002 → ND
#       967350003 → Autres foulons teinture
#   smallapp_foulonretannage → Foulon Retannage
#   smallapp_foulontannage → Foulon Tannage
#
# Table: Programmes (43 colonnes)
#   cr446_Cuve → Cuve
#   cr446_affectation_Programme_cr446_programme → Affectations
#   cr446_choix1 → Choix 1 %
#   cr446_choix1qty → Choix 1 Qty
#   cr446_choix2 → Choix 2 %
#   cr446_choix2qty → Choix 2 Qty
#   cr446_choix3 → Choix 3 %
#   cr446_choix3qty → Choix 3 Qty
#   cr446_codearticle → Code Article
#   cr446_commentaire_Programme_cr446_programme → Commentaires
#   cr446_commentaireprog → Commentaire
#   cr446_datecave → DateCAVE
#   cr446_datedder → DateDDER
#   cr446_datedegr → DateDEGR
#   cr446_datedery → DateDERY
#   cr446_datedmrg → DateDMRG
#   cr446_datemaer → DateMAER
#   cr446_datetann → DateTANN
#   cr446_datetri → DateTRI
#   cr446_decoupe → Découpe
#     📋 Liste de choix (2 valeurs):
#       113790000 → BC
#       113790001 → FC
#   cr446_defaut_Programme_cr446_programme → Défauts
#   cr446_espece → Espèce
#   cr446_essai_Programme_cr446_programme → Essais
#   cr446_etapetri → Etape TRI
#   cr446_numero → Numéro
#   cr446_opencours → Opération en cours
#     📋 Liste de choix (10 valeurs):
#       0 → 0 - Démarrage production
#       1 → 1 - Mise à eau (rivière)
#       2 → 2 - Tannage
#       3 → 3 - Retannage
#       4 → 4 - Cave
#       5 → 5 - Disponible dérayage
#       6 → 6 - Dérayage
#       7 → 7 - Dégraissage
#       8 → 8 - Cadrage
#       9 → 9 - Contrôle qualité
#   cr446_poids → Poids
#   cr446_progid → ProgID
#   cr446_programme_AsyncOperations → Tâches système
#   cr446_programme_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_programme_DuplicateBaseRecord → Enregistrements dupliqués (cr446_programme_DuplicateBaseRecord)
#   cr446_programme_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_programme_DuplicateMatchingRecord)
#   cr446_programme_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_programme_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_programme_ProcessSession → Sessions de traitement
#   cr446_programme_SyncErrors → Erreurs de synchronisation
#   cr446_programmeid → Programme
#   cr446_quantite → Quantité
#   cr446_taille → Taille
#   cr446_tannage → Tannage
#   smallapp_etape → Etape
#   smallapp_familleespece → Famille Espèce
#   smallapp_tri → Tri
#     📋 Liste de choix (2 valeurs):
#       0 → No
#       1 → Yes
#
# Table: Essais (30 colonnes)
#   cr446_Cuve → Cuve (Crocodile)
#   cr446_Emetteurvivoin → Emetteurvivoin
#   cr446_ProgAval → Programme (Aval)
#   cr446_Programme → Programme (Amont)
#   cr446_atelier → Atelier concerné
#   cr446_commentaireessai → Intitulé
#   cr446_description → Description
#   cr446_emetteur → Emetteur
#   cr446_essai_AsyncOperations → Tâches système
#   cr446_essai_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_essai_DuplicateBaseRecord → Enregistrements dupliqués (cr446_essai_DuplicateBaseRecord)
#   cr446_essai_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_essai_DuplicateMatchingRecord)
#   cr446_essai_FileAttachments → FileAttachments
#   cr446_essai_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_essai_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_essai_ProcessSession → Sessions de traitement
#   cr446_essai_SyncErrors → Erreurs de synchronisation
#   cr446_essaiid → Essai
#   cr446_numeroessai → Numéro Essai
#   cr446_photo → Photo
#   cr446_photoid → cr446_PhotoId
#   cr83b_Emetteuravecmail → Emetteur avec mail
#   cr83b_complementpiecesjointes → Complement pieces jointes
#   smallapp_AffectationLotCuve → Partie de sous-lot <> Cuve
#   smallapp_CuveLezard → Cuve (Lézard)
#   smallapp_LotAchat → Lot d'achat
#   smallapp_LotAchatTaille → Sous-lot d'achat
#   smallapp_atelier → Atelier
#     📋 Liste de choix (15 valeurs):
#       579940000 → Agrafage
#       579940001 → Cadrage
#       579940002 → Dégraissage
#       579940003 → Dérayage
#       579940004 → Finition
#       579940005 → Flanche
#       579940006 → Humide
#       579940007 → Lisse
#       579940008 → Magasin Croûte
#       579940009 → Palisson
#       579940010 → Parage
#       579940011 → Qualité
#       579940012 → R&D
#       579940013 → Teinture
#       579940014 → Tri Croûte
#   smallapp_familleespece → Famille Espèce
#   smallapp_statutcloture → Statut clotûre
#     📋 Liste de choix (4 valeurs):
#       579940000 → Concluant
#       579940001 → Non Concluant
#       579940002 → Abandonné
#       579940003 → En cours
#
# Table: Affectations (22 colonnes)
#   cr446_Cuve → Cuve (Crocodile)
#   cr446_ProgAval → Programme (Aval)
#   cr446_Programme → Programme (Amont)
#   cr446_affectation → Affectation (cr446_affectation)
#     📋 Liste de choix (5 valeurs):
#       113790000 → Commande
#       113790001 → Désignation
#       113790002 → Réservation
#       113790003 → Relance
#       113790004 → Recoupe
#   cr446_affectation_AsyncOperations → Tâches système
#   cr446_affectation_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_affectation_DuplicateBaseRecord → Enregistrements dupliqués (cr446_affectation_DuplicateBaseRecord)
#   cr446_affectation_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_affectation_DuplicateMatchingRecord)
#   cr446_affectation_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_affectation_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_affectation_ProcessSession → Sessions de traitement
#   cr446_affectation_SyncErrors → Erreurs de synchronisation
#   cr446_affectationid → Affectation (cr446_affectationid)
#   cr446_espece → Espèce
#   cr446_numeroaffectation → Numéro Affectation
#   cr446_quantite → Quantité
#   cr446_secteurdactivite → Secteur d'activité
#     📋 Liste de choix (8 valeurs):
#       113790000 → Bijouterie
#       113790001 → Ceinture
#       113790002 → Chaussure
#       113790003 → Matière 2 Sac
#       113790004 → PAP Femme
#       113790005 → PAP Homme
#       113790006 → PM
#       113790007 → Sac
#   smallapp_AffectationLotCuve → Partie de sous-lot <> Cuve
#   smallapp_CuveLezard → Cuve (Lézard)
#   smallapp_LotAchat → Lot d'achat
#   smallapp_LotAchatTaille → Sous-lot d'achat
#   smallapp_choixaffectation → Choix Affectation
#
# Table: Défauts (24 colonnes)
#   cr446_Cuve → Cuve (Crocodile)
#   cr446_ProgAval → Programme (Aval)
#   cr446_Programme → Programme (Amont)
#   cr446_codedefaut → Code défaut
#     📋 Liste de choix (11 valeurs):
#       579940001 → B bretelle
#       579940002 → C cicatrice
#       579940003 → DP dépigmentation
#       579940004 → EC ecaille
#       579940005 → EF effleuré
#       579940006 → G griffe
#       579940007 → GE grain éclaté
#       579940008 → P piqué
#       579940009 → PV peau vide
#       579940010 → T trou
#       579940011 → TO tâche orange
#   cr446_commentairedefaut → Description
#   cr446_defaut_AsyncOperations → Tâches système
#   cr446_defaut_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_defaut_DuplicateBaseRecord → Enregistrements dupliqués (cr446_defaut_DuplicateBaseRecord)
#   cr446_defaut_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_defaut_DuplicateMatchingRecord)
#   cr446_defaut_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_defaut_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_defaut_ProcessSession → Sessions de traitement
#   cr446_defaut_SyncErrors → Erreurs de synchronisation
#   cr446_defautid → Défaut
#   cr446_intitule → Intitulé (cr446_intitule)
#   cr446_intituledefaut → Intitulé (cr446_intituledefaut)
#   cr446_numerodefaut → Numéro Défaut
#   cr446_photodefaut → Photo défaut
#   cr446_photodefautid → cr446_PhotoDefautId
#   cr83b_codedefautc → Code defaut C
#     📋 Liste de choix (22 valeurs):
#       967350000 → P pix
#       967350001 → S cicatrice
#       967350002 → Q double ecaille
#       967350003 → G parasite sangsue
#       967350004 → M frisée crispéé
#       967350005 → W wrinkle
#       967350006 → V tâche blanche
#       967350007 → C coupure
#       967350008 → D nombril
#       967350009 → 0 creux blanc
#       967350010 → K bas de fleur
#       967350011 → 1 cloque
#       967350012 → 2 manque cites
#       967350013 → 6 arrêt de poisson
#       967350014 → Y gale
#       967350015 → N trou
#       967350016 → 12 naissance ecaille
#       967350017 → 8 pli de rivière
#       967350018 → 86 moisissure
#       967350019 → J coupure dérayage
#       967350020 → O graisse, gras
#       967350021 → 4 cratère
#   smallapp_AffectationLotCuve → Partie de sous-lot <> Cuve
#   smallapp_CuveLezard → Cuve (Lézard)
#   smallapp_LotAchat → Lot d'achat
#   smallapp_LotAchatTaille → Sous-lot d'achat
#
# Table: Commentaires (21 colonnes)
#   cr446_Cuve → Cuve (Crocodile)
#   cr446_ProgAval → Programme (Aval)
#   cr446_Programme → Programme (Amont)
#   cr446_codecommentaire → Code Commentaire
#   cr446_commentaire_AsyncOperations → Tâches système
#   cr446_commentaire_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_commentaire_DuplicateBaseRecord → Enregistrements dupliqués (cr446_commentaire_DuplicateBaseRecord)
#   cr446_commentaire_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_commentaire_DuplicateMatchingRecord)
#   cr446_commentaire_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_commentaire_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_commentaire_ProcessSession → Sessions de traitement
#   cr446_commentaire_SyncErrors → Erreurs de synchronisation
#   cr446_commentaireid → Commentaire
#   cr446_image → Image
#   cr446_imageid → cr446_ImageId
#   cr446_texte → Texte
#   smallapp_AffectationLotCuve → Partie de sous-lot <> Cuve
#   smallapp_CuveLezard → Cuve (Lézard)
#   smallapp_LotAchat → Lot d'achat
#   smallapp_LotAchatTaille → Sous-lot d'achat
#   smallapp_type → Type
#     📋 Liste de choix (3 valeurs):
#       1 → Classique
#       2 → Qualité
#       3 → Process
#
# Table: Programmes Aval (49 colonnes)
#   cr446_affectation_ProgAval_cr446_programmeaval → Affectations
#   cr446_casier → Casier
#     📋 Liste de choix (52 valeurs):
#       113790000 → A1
#       113790001 → A2
#       113790002 → A3
#       113790003 → A4
#       113790004 → A5
#       113790005 → B1
#       113790006 → B2
#       113790007 → B3
#       113790008 → B4
#       113790009 → B5
#       113790010 → C1
#       113790011 → C2
#       113790012 → C3
#       113790013 → C4
#       113790014 → C5
#       113790015 → D1
#       113790016 → D2
#       113790017 → D3
#       113790018 → D4
#       113790019 → D5
#       113790020 → E1
#       113790021 → E2
#       113790022 → E3
#       113790023 → E4
#       113790024 → E5
#       113790025 → F1
#       113790026 → F2
#       113790027 → F3
#       113790028 → F4
#       113790029 → F5
#       113790030 → G1
#       113790031 → G2
#       113790032 → G3
#       113790033 → G4
#       113790034 → G5
#       113790035 → H1
#       113790036 → H2
#       113790037 → H3
#       113790038 → H4
#       113790039 → H5
#       113790040 → I1
#       113790041 → I2
#       113790042 → I3
#       113790043 → I4
#       113790044 → I5
#       113790045 → Côté étagère A
#       113790046 → Côté étagère B
#       113790047 → Côté étagère C
#       113790048 → Chariot triage
#       113790049 → Chariot côté étagère A
#       113790050 → Derrière cadreuse 1 et 2
#       113790051 → Etagère tri
#   cr446_cdvliee → CDV liée
#   cr446_clientlivre → Client Livré
#   cr446_codearticle → Code Article
#   cr446_codecoloris → Code Coloris
#   cr446_codeespece → Code Espèce
#   cr446_codeetape → Code étape
#   cr446_codefinition → Code Finition
#   cr446_commentaire_ProgAval_cr446_programmeaval → Commentaires
#   cr446_cqfr_ProgAval_cr446_programmeaval → CQFR
#   cr446_cuve_ProgAval_cr446_programmeaval → Cuves Croco
#   cr446_datecommande → Date Commande
#   cr446_dateengagement → Date Engagement
#   cr446_decoupe → Découpe
#   cr446_defaut_ProgAval_cr446_programmeaval → Défauts
#   cr446_designation → Désignation
#   cr446_espece → Espèce
#   cr446_essai_ProgAval_cr446_programmeaval → Essais
#   cr446_etape → Etape
#   cr446_etat → Etat
#   cr446_libellearticle → Libellé Article
#   cr446_libellecoloris → Libellé Coloris
#   cr446_libellefinition → Libellé Finition
#   cr446_master → Master
#   cr446_ncommandeclient → N° Commande Client
#   cr446_poids → Poids
#   cr446_progid → ProgID
#   cr446_programmeaval_AsyncOperations → Tâches système
#   cr446_programmeaval_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_programmeaval_DuplicateBaseRecord → Enregistrements dupliqués (cr446_programmeaval_DuplicateBaseRecord)
#   cr446_programmeaval_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_programmeaval_DuplicateMatchingRecord)
#   cr446_programmeaval_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_programmeaval_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_programmeaval_ProcessSession → Sessions de traitement
#   cr446_programmeaval_SyncErrors → Erreurs de synchronisation
#   cr446_programmeavalid → Programme Aval
#   cr446_pxaaffecter → Px à affecter
#   cr446_pxnecessaires → Px nécessaires
#   cr446_pxrestantes → Px restantes
#   cr446_referencehermes → Référence Hermès
#   cr446_relance → Relance
#   cr446_resa → Résa
#     📋 Liste de choix (2 valeurs):
#       0 → No
#       1 → Yes
#   cr446_taillemax → Taille Max
#   cr446_taillemin → Taille min
#   cr446_typeof → Type OF
#   smallapp_casiercheck → Casier Check
#   smallapp_datecasier → Date Casier
#   smallapp_familleespece → Famille Espèce
#
# Table: Lots Achat (31 colonnes)
#   cr446_familleespece → Famille Espèce
#   cr446_quantitechoix1bc → Quantité Choix 1 BC
#   cr446_quantitechoix2bc → Quantité Choix 2 BC
#   cr446_quantitechoix3bc → Quantité Choix 3 BC
#   smallapp_affectationlotcuve_LotAchat_smallapp_lotachat → Affectation Lot-Cuves
#   smallapp_cr446_affectation_LotAchat_smallapp_lotachat → Affectations
#   smallapp_cr446_commentaire_LotAchat_smallapp_lotachat → Commentaires
#   smallapp_cr446_defaut_LotAchat_smallapp_lotachat → Défauts
#   smallapp_cr446_essai_LotAchat_smallapp_lotachat → Essais
#   smallapp_espece → Espèce
#     📋 Liste de choix (3 valeurs):
#       579940000 → Varanus Niloticus
#       579940001 → Varanus Salvatore SD
#       579940002 → Varanus Salvatore VN
#   smallapp_identifiant → Identifiant
#   smallapp_lotachat_AsyncOperations → Tâches système
#   smallapp_lotachat_BulkDeleteFailures → Échecs des suppressions en bloc
#   smallapp_lotachat_DuplicateBaseRecord → Enregistrements dupliqués (smallapp_lotachat_DuplicateBaseRecord)
#   smallapp_lotachat_DuplicateMatchingRecord → Enregistrements dupliqués (smallapp_lotachat_DuplicateMatchingRecord)
#   smallapp_lotachat_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   smallapp_lotachat_PrincipalObjectAttributeAccesses → Partage de champ
#   smallapp_lotachat_ProcessSession → Sessions de traitement
#   smallapp_lotachat_SyncErrors → Erreurs de synchronisation
#   smallapp_lotachatid → Lot Achat
#   smallapp_lotachattaille_LotAchat_smallapp_lotachat → Lots Achat Taille
#   smallapp_numerolot → Numéro Lot
#   smallapp_origine → Origine
#     📋 Liste de choix (5 valeurs):
#       579940000 → ABI
#       579940001 → BIZ
#       579940002 → VER
#       579940003 → VV
#       579940004 → YOU
#   smallapp_peaux_LotAchat_smallapp_lotachat → Peaux
#   smallapp_quantitebc → Quantité BC
#   smallapp_quantitechoix1 → Quantité Choix 1 FC
#   smallapp_quantitechoix2 → Quantité Choix 2 FC
#   smallapp_quantitechoix3 → Quantité Choix 3 FC
#   smallapp_quantitefc → Quantité FC
#   smallapp_quantiterecue → Quantité Reçue
#   smallapp_quantiterejetee → Quantité Rejetée
#
# Table: Lots Achat Taille (30 colonnes)
#   cr446_espece → Espèce
#   cr446_familleespece → Famille Espèce
#   cr446_origine → Origine
#   cr446_quantitechoix1bc → Quantité Choix 1 BC
#   cr446_quantitechoix2bc → Quantité Choix 2 BC
#   cr446_quantitechoix3bc → Quantité Choix 3 BC
#   cr446_quantiterejetee → Quantité Rejetée
#   smallapp_LotAchat → Lot Achat
#   smallapp_affectationlotcuve_LotAchatTaille_smallapp_lotachattaille → Affectation Lot-Cuves
#   smallapp_cr446_affectation_LotAchatTaille_smallapp_lotachattaille → Affectations
#   smallapp_cr446_commentaire_LotAchatTaille_smallapp_lotachattaille → Commentaires
#   smallapp_cr446_defaut_LotAchatTaille_smallapp_lotachattaille → Défauts
#   smallapp_cr446_essai_LotAchatTaille_smallapp_lotachattaille → Essais
#   smallapp_identifiant → Identifiant
#   smallapp_lotachattaille_AsyncOperations → Tâches système
#   smallapp_lotachattaille_BulkDeleteFailures → Échecs des suppressions en bloc
#   smallapp_lotachattaille_DuplicateBaseRecord → Enregistrements dupliqués (smallapp_lotachattaille_DuplicateBaseRecord)
#   smallapp_lotachattaille_DuplicateMatchingRecord → Enregistrements dupliqués (smallapp_lotachattaille_DuplicateMatchingRecord)
#   smallapp_lotachattaille_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   smallapp_lotachattaille_PrincipalObjectAttributeAccesses → Partage de champ
#   smallapp_lotachattaille_ProcessSession → Sessions de traitement
#   smallapp_lotachattaille_SyncErrors → Erreurs de synchronisation
#   smallapp_lotachattailleid → Lot Achat Taille
#   smallapp_peaux_LotAchatTaille_smallapp_lotachattaille → Peaux
#   smallapp_quantitebc → Quantité BC
#   smallapp_quantitechoix1 → Quantité Choix 1 FC
#   smallapp_quantitechoix2 → Quantité Choix 2 FC
#   smallapp_quantitechoix3 → Quantité Choix 3 FC
#   smallapp_quantitefc → Quantité FC
#   smallapp_taille → Taille
#     📋 Liste de choix (22 valeurs):
#       579940000 → 19-
#       579940001 → 20
#       579940002 → 21
#       579940003 → 22
#       579940004 → 23
#       579940005 → 24
#       579940006 → 25
#       579940007 → 26
#       579940008 → 27
#       579940009 → 28
#       579940010 → 29
#       579940011 → 30
#       579940012 → 31
#       579940013 → 32
#       579940014 → 33
#       579940015 → 34
#       579940016 → 35
#       579940017 → 36
#       579940018 → 37
#       579940019 → 38
#       579940020 → 39
#       579940021 → 40+
#
# Table: Peaux (22 colonnes)
#   smallapp_AffectationLotCuve → Affectation Lot-Cuve
#   smallapp_Cuve → Cuve Lézard
#   smallapp_LotAchat → Lot Achat
#   smallapp_LotAchatTaille → Lot Achat Taille
#   smallapp_choix → Choix
#   smallapp_choixcroute → Choix Croute
#   smallapp_choixhermes → Choix Hermès
#   smallapp_decoupe → Découpe
#   smallapp_emplacementcroute → Emplacement Croute
#   smallapp_modelecroute → Modèle Croute
#     📋 Liste de choix (56 valeurs):
#       579940000 → AZAP INTEGRAL
#       579940001 → BANGLE OLYMPE
#       579940002 → BEARN COMPACT
#       579940003 → BIRKIN 25
#       579940004 → BIRKIN 30
#       579940005 → BIRKIN SELLIER 20
#       579940006 → BIRKIN SELLIER 20 SERTI
#       579940007 → BK 25 TOUCH
#       579940008 → BOLIDE MINI 1923
#       579940009 → BOLIDE TOUCH
#       579940010 → BOUCLE OREILLES OLYMPE
#       579940011 → CALVI
#       579940012 → CALVI DUO
#       579940013 → CHAINE D'ANCRE COMPACT
#       579940014 → COFFRET AMALTHEE PM
#       579940015 → COLLIER DE CHIEN
#       579940016 → COLLIER DE CHIEN 24
#       579940017 → CONSTANCE 1-24
#       579940018 → CONSTANCE III MINI
#       579940019 → CONSTANCE III MINI MIROIR
#       579940020 → CONSTANCE MICRO
#       579940021 → CONSTANCE SLIM COMPACT
#       579940022 → CONSTANCE TO GO
#       579940023 → ETUI MONTRE GM
#       579940024 → ETUI MONTRE PM
#       579940025 → H CHAUSSURE GLAMOUR FULL
#       579940026 → HACABOX
#       579940027 → HERMES GANTS
#       579940028 → HERMES MINUIT AU FAUBOURG 20
#       579940029 → ILIADE PORTE-CARTES
#       579940030 → JIGE ELAN TOUCH
#       579940031 → JOY 105, FULL MODELE
#       579940032 → KELLY DANSE II
#       579940033 → KELLY DEPECHES 25
#       579940034 → KELLY DOUBLE TOUR
#       579940035 → KELLY ELAN
#       579940036 → KELLY FESTIVAL
#       579940037 → KELLY II SELLIER 25
#       579940038 → KELLY II SELLIER 25 KELLYOPTIC
#       579940039 → KELLY II SELLIER 28
#       579940040 → KELLY II SELLIER MINI
#       579940041 → KELLY II SELLIER MINI TOUCH
#       579940042 → KELLY MESSENGER PM
#       579940043 → KELLY MINI
#       579940044 → KELLY TO GO
#       579940045 → MAH-JONG
#       579940046 → OASIS FEMME H PUNTINA FILETTO
#       579940047 → PICOTIN LOCL MICRO
#       579940048 → POCHETTE KELLY MINI
#       579940049 → ROULIS MINI
#       579940050 → ROULIS SLIM COMPACT
#       579940051 → SAC A DEPECHES 21
#       579940052 → SAC A DEPECHES 24
#       579940053 → TOUCH 3 KELLY RET 25
#       579940054 → TWIST PM
#       579940055 → VERROU CHAINE MINI
#   smallapp_peaux_AsyncOperations → Tâches système
#   smallapp_peaux_BulkDeleteFailures → Échecs des suppressions en bloc
#   smallapp_peaux_DuplicateBaseRecord → Enregistrements dupliqués (smallapp_peaux_DuplicateBaseRecord)
#   smallapp_peaux_DuplicateMatchingRecord → Enregistrements dupliqués (smallapp_peaux_DuplicateMatchingRecord)
#   smallapp_peaux_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   smallapp_peaux_PrincipalObjectAttributeAccesses → Partage de champ
#   smallapp_peaux_ProcessSession → Sessions de traitement
#   smallapp_peaux_SyncErrors → Erreurs de synchronisation
#   smallapp_peauxid → Peaux
#   smallapp_rfid → RFID
#   smallapp_taille → Taille
#   smallapp_taillecroute → Taille Croute
#
# Table: CQFR (38 colonnes)
#   cr446_Cuve → Cuve (Crocodile)
#   cr446_ProgAval → Programme (Aval)
#   cr446_brillance → Brillance %
#   cr446_commentairequalite → Commentaire Qualité
#   cr446_cqfr_AsyncOperations → Tâches système
#   cr446_cqfr_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_cqfr_DuplicateBaseRecord → Enregistrements dupliqués (cr446_cqfr_DuplicateBaseRecord)
#   cr446_cqfr_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_cqfr_DuplicateMatchingRecord)
#   cr446_cqfr_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_cqfr_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_cqfr_ProcessSession → Sessions de traitement
#   cr446_cqfr_SyncErrors → Erreurs de synchronisation
#   cr446_cqfrid → CQFR
#   cr446_espece → Espèce
#   cr446_homogeneite → Homogénéité %
#   cr446_libellearticle → Libellé Article
#   cr446_libellecoloris → Libellé Coloris
#   cr446_libellefinition → Libellé Finition
#   cr446_numero → Numero
#   cr446_quantite → Quantité
#   cr446_souplesse → Souplesse %
#   cr446_spectro → Spectro
#   cr446_taillemax → Taille Max
#   cr446_taillemin → Taille Min
#   cr446_touche → Touché %
#   smallapp_familleespece → Famille Espèce
#   smallapp_modele → Modèle
#   smallapp_quantitelivree → Quantité livrée
#   smallapp_quantiterebutrejet → Quantité rebut/rejet
#   smallapp_resultatveslichumidecuir → Résultat Veslic Humide Cuir
#     📋 Liste de choix (12 valeurs):
#       579940000 → 0
#       579940001 → 0-1
#       579940002 → 1
#       579940003 → 1-2
#       579940004 → 2
#       579940005 → 2-3
#       579940006 → 3
#       579940007 → 3-4
#       579940008 → 4
#       579940009 → 4-5
#       579940010 → 5
#       579940011 → N/A
#   smallapp_resultatveslichumidefeutre → Résultat Veslic Humide Feutre
#   smallapp_resultatveslicseccuir → Résultat Veslic Sec Cuir
#   smallapp_resultatveslicsecfeutre → Résultat Veslic Sec Feutre
#   smallapp_testpvc → Test PVC
#   smallapp_testscotch → Test Scotch
#   smallapp_uv12h → UV12h
#   smallapp_uv24h → UV24h
#   smallapp_uv6h → UV6H
#
# Table: Affectations Lot-Cuve (25 colonnes)
#   cr446_espece → Espèce
#   smallapp_CuveLezard → Cuve Lézard
#   smallapp_LotAchat → Lot Achat
#   smallapp_LotAchatTaille → Lot Achat Taille
#   smallapp_affectationlotcuve_AsyncOperations → Tâches système
#   smallapp_affectationlotcuve_BulkDeleteFailures → Échecs des suppressions en bloc
#   smallapp_affectationlotcuve_DuplicateBaseRecord → Enregistrements dupliqués (smallapp_affectationlotcuve_DuplicateBaseRecord)
#   smallapp_affectationlotcuve_DuplicateMatchingRecord → Enregistrements dupliqués (smallapp_affectationlotcuve_DuplicateMatchingRecord)
#   smallapp_affectationlotcuve_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   smallapp_affectationlotcuve_PrincipalObjectAttributeAccesses → Partage de champ
#   smallapp_affectationlotcuve_ProcessSession → Sessions de traitement
#   smallapp_affectationlotcuve_SyncErrors → Erreurs de synchronisation
#   smallapp_affectationlotcuveid → Affectation Lot-Cuve
#   smallapp_cr446_affectation_AffectationLotCuve_smallapp_affectationlotcuve → Affectations
#   smallapp_cr446_commentaire_AffectationLotCuve_smallapp_affectationlotcuve → Commentaires
#   smallapp_cr446_defaut_AffectationLotCuve_smallapp_affectationlotcuve → Défauts
#   smallapp_cr446_essai_AffectationLotCuve_smallapp_affectationlotcuve → Essais
#   smallapp_identifiant → Identifiant
#   smallapp_peaux_AffectationLotCuve_smallapp_affectationlotcuve → Peaux
#   smallapp_quantitebc → Quantité BC
#   smallapp_quantitechoix1 → Quantité Choix 1
#   smallapp_quantitechoix2 → Quantité Choix 2
#   smallapp_quantitechoix3 → Quantité Choix 3
#   smallapp_quantitefc → Quantité FC
#   smallapp_quantitetotale → Quantité Totale
#
# Table: Cuves Lézard (33 colonnes)
#   smallapp_affectationlotcuve_CuveLezard_smallapp_cuvelezard → Affectation Lot-Cuves
#   smallapp_cr446_affectation_CuveLezard_smallapp_cuvelezard → Affectations
#   smallapp_cr446_commentaire_CuveLezard_smallapp_cuvelezard → Commentaires
#   smallapp_cr446_defaut_CuveLezard_smallapp_cuvelezard → Défauts
#   smallapp_cr446_essai_CuveLezard_smallapp_cuvelezard → Essais
#   smallapp_cuvelezard_AsyncOperations → Tâches système
#   smallapp_cuvelezard_BulkDeleteFailures → Échecs des suppressions en bloc
#   smallapp_cuvelezard_DuplicateBaseRecord → Enregistrements dupliqués (smallapp_cuvelezard_DuplicateBaseRecord)
#   smallapp_cuvelezard_DuplicateMatchingRecord → Enregistrements dupliqués (smallapp_cuvelezard_DuplicateMatchingRecord)
#   smallapp_cuvelezard_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   smallapp_cuvelezard_PrincipalObjectAttributeAccesses → Partage de champ
#   smallapp_cuvelezard_ProcessSession → Sessions de traitement
#   smallapp_cuvelezard_SyncErrors → Erreurs de synchronisation
#   smallapp_cuvelezardid → Cuve Lézard
#   smallapp_datemae → Date MAE
#   smallapp_datetri → Date Tri
#   smallapp_espece → Espèce
#   smallapp_etape → Etape
#   smallapp_etapeauto → Etape Auto
#   smallapp_etat → Etat
#   smallapp_famille → Famille
#   smallapp_foulonretannage → Foulon Retannage
#   smallapp_foulonriviere → Foulon Rivière
#   smallapp_foulontannage → Foulon Tannage
#   smallapp_numero → Numéro
#   smallapp_peaux_Cuve_smallapp_cuvelezard → Peaux
#   smallapp_poids → Poids
#   smallapp_quantitebc → Quantité BC
#   smallapp_quantitechoix1 → Quantité Choix 1
#   smallapp_quantitechoix2 → Quantité Choix 2
#   smallapp_quantitechoix3 → Quantité Choix 3
#   smallapp_quantitefc → Quantité FC
#   smallapp_quantitemae → Quantité MAE
#
# === OPTIONS D'EXPORT ===
# 1. Mermaid (pour diagramme ER)
# 2. JSON structuré (complet)
# 3. CSV des tables et colonnes
# 4. XML
# 5. Tous les formats
#
# 🎉 Extraction terminée !

# %%
import json
import re
from collections import defaultdict

# Charger le fichier DataSources.json
with open('DataSources.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Accéder à la liste des DataSources
data_sources = data["DataSources"]

# Tables à exclure
excluded_tables = ["Divisions", "Utilisateurs"]

# Colonnes systèmes à exclure
excluded_columns = {
    "utcconversiontimezonecode", "_ownerid_value", "statuscode", "statecode",
    "modifiedonbehalfby", "createdonbehalfby", "owninguser", "timezoneruleversionnumber",
    "owningbusinessunit", "modifiedon", "modifiedby", "versionnumber",
    "overriddencreatedon", "createdby", "importsequencenumber", "owningteam", "createdon"
}

# Dictionnaire pour stocker les tables et leurs colonnes
tables = {}

# Dictionnaire pour les Option Sets
option_sets = {}
option_sets_by_column = {}  # Pour lier rapidement colonne -> choix

# Extraire d'abord tous les Option Sets
for ds in data_sources:
    if ds.get("Type") == "OptionSetInfo":
        option_set_name = ds.get("Name")
        related_entity = ds.get("RelatedEntityName")
        related_column = ds.get("RelatedColumnInvariantName")
        option_mapping = ds.get("OptionSetInfoNameMapping", {})
        
        if option_set_name and related_entity and related_column:
            key = f"{related_entity}.{related_column}"
            option_sets_by_column[key] = option_mapping

# Parcourir les DataSources pour les tables
for ds in data_sources:
    if ds.get("Type") == "NativeCDSDataSourceInfo":
        table_name = ds.get("Name") or ds.get("LogicalName") or ds.get("EntitySetName")
        if not table_name or table_name in excluded_tables:
            continue
            
        columns_detail = {}
        name_mapping = ds.get("NativeCDSDataSourceInfoNameMapping", {})
        
        if name_mapping:
            for technical_name, display_name in name_mapping.items():
                if technical_name in excluded_columns:
                    continue
                columns_detail[technical_name] = display_name
        
        tables[table_name] = columns_detail

# Afficher les tables avec leurs colonnes et listes de choix
print("=== LISTE DES TABLES AVEC COLONNES ET LISTES DE CHOIX ===")

for table, cols in tables.items():
    print(f"\nTable: {table} ({len(cols)} colonnes)")
    for tech_name, display_name in sorted(cols.items()):
        print(f"  {tech_name} → {display_name}")
        
        # Vérifier s'il y a une liste de choix pour cette colonne
        option_key = f"{table}.{tech_name}"
        if option_key in option_sets_by_column:
            options = option_sets_by_column[option_key]
            print(f"    📋 Liste de choix ({len(options)} valeurs):")
            for key, value in sorted(options.items()):
                print(f"      {key} → {value}")

# Export vers format MERMAID pour graphique d'architecture

# Fonction pour nettoyer les noms pour Mermaid
def clean_mermaid_name(name):
    # Remplacer les caractères problématiques
    cleaned = re.sub(r'[^a-zA-Z0-9_]', '_', name)
    # S'assurer qu'il ne commence pas par un chiffre
    if cleaned and cleaned[0].isdigit():
        cleaned = "attr_" + cleaned
    return cleaned if cleaned else "unnamed_attr"

# Fonction pour générer le diagramme Mermaid avec la bonne syntaxe
def generate_mermaid_graph(tables):
    mermaid_lines = ["```mermaid", "erDiagram"]
    
    # Ajouter les entités avec la syntaxe correcte
    for table, cols in tables.items():
        clean_table = clean_mermaid_name(table)
        
        mermaid_lines.append(f'    {clean_table} {{')
        
        # Ajouter les attributs (limité à 10 pour la lisibilité)
        for i, (tech_name, display_name) in enumerate(list(cols.items())[:10]):
            clean_attr = clean_mermaid_name(tech_name)
            # Syntaxe correcte : type nom
            mermaid_lines.append(f'        string {clean_attr} "{display_name}"')
        
        if len(cols) > 10:
            mermaid_lines.append(f'        string other "... et {len(cols) - 10} autres colonnes"')
            
        mermaid_lines.append('    }')
    
    # Ajouter quelques relations basiques
    for table, cols in tables.items():
        clean_table = clean_mermaid_name(table)
        for col_name in cols.keys():
            if col_name.endswith('id') and col_name != 'id':
                target_table = col_name[:-2]  # Enlever 'id'
                if target_table in tables:
                    clean_target = clean_mermaid_name(target_table)
                    clean_col = clean_mermaid_name(col_name)
                    mermaid_lines.append(f'    {clean_target} ||--o{{ {clean_table} : "{col_name}"')
    
    mermaid_lines.append("```")
    return "\n".join(mermaid_lines)

# Export vers format JSON structuré
def generate_structured_json():
    architecture = {
        "tables": {},
        "relationships": [],
        "option_sets": {}
    }
    
    # Tables et colonnes
    for table, cols in tables.items():
        architecture["tables"][table] = {
            "columns": cols,
            "option_sets": {}
        }
        
        # Ajouter les option sets pour cette table
        for col_name in cols.keys():
            option_key = f"{table}.{col_name}"
            if option_key in option_sets_by_column:
                architecture["tables"][table]["option_sets"][col_name] = option_sets_by_column[option_key]
    
    # Relations basiques
    for table, cols in tables.items():
        for col_name in cols.keys():
            if col_name.endswith('id') and col_name != 'id':
                target_table = col_name[:-2]
                if target_table in tables:
                    architecture["relationships"].append({
                        "from_table": target_table,
                        "to_table": table,
                        "column": col_name,
                        "type": "lookup"
                    })
    
    return architecture

# Export pour Drawio
def clean_xml_text(text):
    """Nettoyer le texte pour XML"""
    if not text:
        return ""
    return text.replace("&", "&amp;").replace("<", "&lt;").replace(">", "&gt;").replace('"', "&quot;")

def generate_drawio_no_relations(tables, option_sets_by_column):
    xml_lines = [
        '<?xml version="1.0" encoding="UTF-8"?>',
        '<mxfile host="app.diagrams.net">',
        '<diagram name="Architecture Power Apps" id="architecture-powerapps">',
        '<mxGraphModel dx="1426" dy="745" grid="1" gridSize="10" guides="1" tooltips="1" connect="1">'
    ]
    
    xml_lines.append('<root>')
    xml_lines.append('<mxCell id="0"/>')
    xml_lines.append('<mxCell id="1" parent="0"/>')
    
    # Générer les tables avec toutes les colonnes
    x_pos = 20
    y_pos = 20
    table_positions = {}  # Pour usage futur
    
    for i, (table, cols) in enumerate(tables.items()):
        table_id = f"table_{i}"
        table_positions[table] = {
            'id': table_id,
            'x': x_pos + (i % 3) * 300,  # 3 colonnes max
            'y': y_pos + (i // 3) * 400   # Nouvelle ligne tous les 3
        }
        
        # Hauteur calculée selon le nombre de colonnes
        table_height = 50 + min(len(cols) * 26, 600)  # Max 600px
        
        # Table swimlane
        xml_lines.append(f'<mxCell id="{table_id}" value="{clean_xml_text(table)}" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=30;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;swimlaneFillColor=#ffffff;fillColor=#e0f7fa;" vertex="1" parent="1">')
        xml_lines.append(f'  <mxGeometry x="{table_positions[table]["x"]}" y="{table_positions[table]["y"]}" width="280" height="{table_height}" as="geometry"/>')
        xml_lines.append('</mxCell>')
        
        # Ajouter les colonnes
        current_y = 30
        for j, (tech_name, display_name) in enumerate(cols.items()):
            if j >= 60:  # Limite pour éviter les diagrammes trop lourds
                # Ajouter une ligne "et X autres"
                remaining = len(cols) - 60
                if remaining > 0:
                    attr_id = f"{table_id}_attr_remaining"
                    xml_lines.append(f'<mxCell id="{attr_id}" value="... et {remaining} autres colonnes" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=middle;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;" vertex="1" parent="{table_id}">')
                    xml_lines.append(f'  <mxGeometry y="{current_y}" width="280" height="26" as="geometry"/>')
                    xml_lines.append('</mxCell>')
                break
                
            attr_id = f"{table_id}_attr_{j}"
            display_text = display_name if display_name else tech_name
            
            # Vérifier s'il y a une liste de choix
            option_key = f"{table}.{tech_name}"
            if option_key in option_sets_by_column:
                options = option_sets_by_column[option_key]
                # Ajouter les valeurs possibles
                option_values = ", ".join(list(options.values())[:3])  # Max 3 valeurs
                if len(options) > 3:
                    option_values += ", ..."
                display_text = f"{display_text} [choix: {option_values}]"
            
            # Style différent pour les colonnes avec listes de choix
            style = "text;strokeColor=none;fillColor=none;align=left;verticalAlign=middle;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;"
            if option_key in option_sets_by_column:
                style = "text;strokeColor=none;fillColor=#fff3e0;align=left;verticalAlign=middle;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;"
            
            xml_lines.append(f'<mxCell id="{attr_id}" value="{clean_xml_text(display_text)}" style="{style}" vertex="1" parent="{table_id}">')
            xml_lines.append(f'  <mxGeometry y="{current_y}" width="280" height="26" as="geometry"/>')
            xml_lines.append('</mxCell>')
            
            current_y += 26
    
    xml_lines.append('</root>')
    xml_lines.append('</mxGraphModel>')
    xml_lines.append('</diagram>')
    xml_lines.append('</mxfile>')
    
    with open('architecture_drawio.xml', 'w', encoding='utf-8') as f:
        f.write('\n'.join(xml_lines))
    
    print("✅ Fichier 'architecture_drawio.xml' généré")
    print("Nombre de tables: ", len(tables))
    total_cols = sum(len(cols) for cols in tables.values())
    print("Nombre total de colonnes: ", total_cols)

# Proposer les exports
print(f"\n=== OPTIONS D'EXPORT ===")
print("1. Mermaid (pour diagramme ER)")
print("2. JSON structuré (complet)")
print("3. CSV des tables et colonnes")
print("4. XML")
print("5. Tous les formats")

choice = input("Quel format voulez-vous générer ? (1/2/3/4/5): ").strip()

if choice in ['1', '5']:
    mermaid_content = generate_mermaid_graph(tables)
    with open('architecture_mermaid.md', 'w', encoding='utf-8') as f:
        f.write("# Architecture des données\n\n")
        f.write(mermaid_content)
    print("✅ Fichier 'architecture_mermaid.md' généré")

if choice in ['2', '5']:
    structured_data = generate_structured_json()
    with open('architecture_complete.json', 'w', encoding='utf-8') as f:
        json.dump(structured_data, f, indent=2, ensure_ascii=False)
    print("✅ Fichier 'architecture_complete.json' généré")

if choice in ['3', '5']:
    with open('tables_colonnes.csv', 'w', encoding='utf-8') as f:
        f.write("Table;Nom Technique;Nom Affiché;Avec Liste de Choix\n")
        for table, cols in tables.items():
            for tech_name, display_name in cols.items():
                has_options = "Oui" if f"{table}.{tech_name}" in option_sets_by_column else "Non"
                f.write(f"{table};{tech_name};{display_name};{has_options}\n")
    print("✅ Fichier 'tables_colonnes.csv' généré")

if choice in ['4', '5']:
    # Utilisation dans ton script principal
    generate_drawio_no_relations(tables, option_sets_by_column)

print("\n🎉 Extraction terminée !")
# Out:
# === LISTE DES TABLES AVEC COLONNES ET LISTES DE CHOIX ===
#
# Table: Cuves (42 colonnes)
#   cr446_ProgAval → ProgAval
#   cr446_affectation_cuve_cr446_cuve → Affectations
#   cr446_affectee → % Affectée
#   cr446_choix1percent → % Choix 1
#   cr446_choix2percent → % Choix 2
#   cr446_choix3percent → % Choix 3
#   cr446_commentaire_Cuve_cr446_cuve → Commentaires
#   cr446_commentairecuve → Commentaire
#   cr446_cqfr_Cuve_cr446_cuve → CQFR
#   cr446_cuve_AsyncOperations → Tâches système
#   cr446_cuve_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_cuve_DuplicateBaseRecord → Enregistrements dupliqués (cr446_cuve_DuplicateBaseRecord)
#   cr446_cuve_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_cuve_DuplicateMatchingRecord)
#   cr446_cuve_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_cuve_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_cuve_ProcessSession → Sessions de traitement
#   cr446_cuve_SyncErrors → Erreurs de synchronisation
#   cr446_cuveid → Cuve
#   cr446_dateetape → Date Etape
#   cr446_defaut_Cuve_cr446_cuve → Défauts
#   cr446_espece → Espèce
#     📋 Liste de choix (5 valeurs):
#       113790000 → Alligator
#       113790001 → Niloticus
#       113790002 → Porosus
#       967350001 → Iguane
#       967350002 → Java
#   cr446_essai_Cuve_cr446_cuve → Essais
#   cr446_etape → Etape
#   cr446_etapetri → EtapeTri
#   cr446_numero → Numéro
#   cr446_poids → Poids
#   cr446_poidstxt → PoidsTxt
#   cr446_priorite → Priorité
#     📋 Liste de choix (5 valeurs):
#       113790000 → Basse
#       113790001 → Moyenne
#       113790002 → Elevée
#       113790003 → Urgente
#       113790004 → Bloquée
#   cr446_programme_Cuve_cr446_cuve → Programmes Amont
#   cr446_qtyaffectee → Qty Affectée
#   cr446_qtychoix1 → Qty Choix 1
#   cr446_qtychoix2 → Qty Choix 2
#   cr446_qtychoix3 → Qty Choix 3
#   cr446_quantite → Quantité
#   cr446_quantitetxt → QuantitéTxt
#   cr446_taille → Taille
#     📋 Liste de choix (9 valeurs):
#       1 → 19-
#       2 → 20-24
#       3 → 25-29
#       4 → 30-34
#       5 → 35-39
#       6 → 40-44
#       7 → 45-49
#       8 → 50-54
#       9 → 55-59
#   cr446_tannage → Tannage
#     📋 Liste de choix (9 valeurs):
#       113790000 → Barolo
#       113790001 → Chantilly
#       113790002 → Classique
#       113790003 → Externe
#       113790004 → Himalaya
#       113790005 → Himalaya SCSB
#       113790006 → Jungle
#       113790007 → Sans Bisphenol
#       113790008 → Sans Chrome
#   smallapp_etat → Etat
#   smallapp_familleespece → Famille Espèce
#     📋 Liste de choix (2 valeurs):
#       579940000 → Crocodile
#       579940001 → Lézard
#   smallapp_foulon → Foulon Rivière
#     📋 Liste de choix (14 valeurs):
#       579940000 → PT1
#       579940001 → PT2
#       579940002 → PT3
#       579940003 → PR1
#       579940004 → PR2
#       579940005 → PR3
#       579940006 → GT1
#       579940007 → GT2
#       579940008 → GT3
#       579940009 → GR1
#       579940010 → GR2
#       967350001 → NA
#       967350002 → ND
#       967350003 → Autres foulons teinture
#   smallapp_foulonretannage → Foulon Retannage
#   smallapp_foulontannage → Foulon Tannage
#
# Table: Programmes (43 colonnes)
#   cr446_Cuve → Cuve
#   cr446_affectation_Programme_cr446_programme → Affectations
#   cr446_choix1 → Choix 1 %
#   cr446_choix1qty → Choix 1 Qty
#   cr446_choix2 → Choix 2 %
#   cr446_choix2qty → Choix 2 Qty
#   cr446_choix3 → Choix 3 %
#   cr446_choix3qty → Choix 3 Qty
#   cr446_codearticle → Code Article
#   cr446_commentaire_Programme_cr446_programme → Commentaires
#   cr446_commentaireprog → Commentaire
#   cr446_datecave → DateCAVE
#   cr446_datedder → DateDDER
#   cr446_datedegr → DateDEGR
#   cr446_datedery → DateDERY
#   cr446_datedmrg → DateDMRG
#   cr446_datemaer → DateMAER
#   cr446_datetann → DateTANN
#   cr446_datetri → DateTRI
#   cr446_decoupe → Découpe
#     📋 Liste de choix (2 valeurs):
#       113790000 → BC
#       113790001 → FC
#   cr446_defaut_Programme_cr446_programme → Défauts
#   cr446_espece → Espèce
#   cr446_essai_Programme_cr446_programme → Essais
#   cr446_etapetri → Etape TRI
#   cr446_numero → Numéro
#   cr446_opencours → Opération en cours
#     📋 Liste de choix (10 valeurs):
#       0 → 0 - Démarrage production
#       1 → 1 - Mise à eau (rivière)
#       2 → 2 - Tannage
#       3 → 3 - Retannage
#       4 → 4 - Cave
#       5 → 5 - Disponible dérayage
#       6 → 6 - Dérayage
#       7 → 7 - Dégraissage
#       8 → 8 - Cadrage
#       9 → 9 - Contrôle qualité
#   cr446_poids → Poids
#   cr446_progid → ProgID
#   cr446_programme_AsyncOperations → Tâches système
#   cr446_programme_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_programme_DuplicateBaseRecord → Enregistrements dupliqués (cr446_programme_DuplicateBaseRecord)
#   cr446_programme_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_programme_DuplicateMatchingRecord)
#   cr446_programme_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_programme_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_programme_ProcessSession → Sessions de traitement
#   cr446_programme_SyncErrors → Erreurs de synchronisation
#   cr446_programmeid → Programme
#   cr446_quantite → Quantité
#   cr446_taille → Taille
#   cr446_tannage → Tannage
#   smallapp_etape → Etape
#   smallapp_familleespece → Famille Espèce
#   smallapp_tri → Tri
#     📋 Liste de choix (2 valeurs):
#       0 → No
#       1 → Yes
#
# Table: Essais (30 colonnes)
#   cr446_Cuve → Cuve (Crocodile)
#   cr446_Emetteurvivoin → Emetteurvivoin
#   cr446_ProgAval → Programme (Aval)
#   cr446_Programme → Programme (Amont)
#   cr446_atelier → Atelier concerné
#   cr446_commentaireessai → Intitulé
#   cr446_description → Description
#   cr446_emetteur → Emetteur
#   cr446_essai_AsyncOperations → Tâches système
#   cr446_essai_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_essai_DuplicateBaseRecord → Enregistrements dupliqués (cr446_essai_DuplicateBaseRecord)
#   cr446_essai_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_essai_DuplicateMatchingRecord)
#   cr446_essai_FileAttachments → FileAttachments
#   cr446_essai_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_essai_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_essai_ProcessSession → Sessions de traitement
#   cr446_essai_SyncErrors → Erreurs de synchronisation
#   cr446_essaiid → Essai
#   cr446_numeroessai → Numéro Essai
#   cr446_photo → Photo
#   cr446_photoid → cr446_PhotoId
#   cr83b_Emetteuravecmail → Emetteur avec mail
#   cr83b_complementpiecesjointes → Complement pieces jointes
#   smallapp_AffectationLotCuve → Partie de sous-lot <> Cuve
#   smallapp_CuveLezard → Cuve (Lézard)
#   smallapp_LotAchat → Lot d'achat
#   smallapp_LotAchatTaille → Sous-lot d'achat
#   smallapp_atelier → Atelier
#     📋 Liste de choix (15 valeurs):
#       579940000 → Agrafage
#       579940001 → Cadrage
#       579940002 → Dégraissage
#       579940003 → Dérayage
#       579940004 → Finition
#       579940005 → Flanche
#       579940006 → Humide
#       579940007 → Lisse
#       579940008 → Magasin Croûte
#       579940009 → Palisson
#       579940010 → Parage
#       579940011 → Qualité
#       579940012 → R&D
#       579940013 → Teinture
#       579940014 → Tri Croûte
#   smallapp_familleespece → Famille Espèce
#   smallapp_statutcloture → Statut clotûre
#     📋 Liste de choix (4 valeurs):
#       579940000 → Concluant
#       579940001 → Non Concluant
#       579940002 → Abandonné
#       579940003 → En cours
#
# Table: Affectations (22 colonnes)
#   cr446_Cuve → Cuve (Crocodile)
#   cr446_ProgAval → Programme (Aval)
#   cr446_Programme → Programme (Amont)
#   cr446_affectation → Affectation (cr446_affectation)
#     📋 Liste de choix (5 valeurs):
#       113790000 → Commande
#       113790001 → Désignation
#       113790002 → Réservation
#       113790003 → Relance
#       113790004 → Recoupe
#   cr446_affectation_AsyncOperations → Tâches système
#   cr446_affectation_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_affectation_DuplicateBaseRecord → Enregistrements dupliqués (cr446_affectation_DuplicateBaseRecord)
#   cr446_affectation_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_affectation_DuplicateMatchingRecord)
#   cr446_affectation_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_affectation_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_affectation_ProcessSession → Sessions de traitement
#   cr446_affectation_SyncErrors → Erreurs de synchronisation
#   cr446_affectationid → Affectation (cr446_affectationid)
#   cr446_espece → Espèce
#   cr446_numeroaffectation → Numéro Affectation
#   cr446_quantite → Quantité
#   cr446_secteurdactivite → Secteur d'activité
#     📋 Liste de choix (8 valeurs):
#       113790000 → Bijouterie
#       113790001 → Ceinture
#       113790002 → Chaussure
#       113790003 → Matière 2 Sac
#       113790004 → PAP Femme
#       113790005 → PAP Homme
#       113790006 → PM
#       113790007 → Sac
#   smallapp_AffectationLotCuve → Partie de sous-lot <> Cuve
#   smallapp_CuveLezard → Cuve (Lézard)
#   smallapp_LotAchat → Lot d'achat
#   smallapp_LotAchatTaille → Sous-lot d'achat
#   smallapp_choixaffectation → Choix Affectation
#
# Table: Défauts (24 colonnes)
#   cr446_Cuve → Cuve (Crocodile)
#   cr446_ProgAval → Programme (Aval)
#   cr446_Programme → Programme (Amont)
#   cr446_codedefaut → Code défaut
#     📋 Liste de choix (11 valeurs):
#       579940001 → B bretelle
#       579940002 → C cicatrice
#       579940003 → DP dépigmentation
#       579940004 → EC ecaille
#       579940005 → EF effleuré
#       579940006 → G griffe
#       579940007 → GE grain éclaté
#       579940008 → P piqué
#       579940009 → PV peau vide
#       579940010 → T trou
#       579940011 → TO tâche orange
#   cr446_commentairedefaut → Description
#   cr446_defaut_AsyncOperations → Tâches système
#   cr446_defaut_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_defaut_DuplicateBaseRecord → Enregistrements dupliqués (cr446_defaut_DuplicateBaseRecord)
#   cr446_defaut_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_defaut_DuplicateMatchingRecord)
#   cr446_defaut_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_defaut_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_defaut_ProcessSession → Sessions de traitement
#   cr446_defaut_SyncErrors → Erreurs de synchronisation
#   cr446_defautid → Défaut
#   cr446_intitule → Intitulé (cr446_intitule)
#   cr446_intituledefaut → Intitulé (cr446_intituledefaut)
#   cr446_numerodefaut → Numéro Défaut
#   cr446_photodefaut → Photo défaut
#   cr446_photodefautid → cr446_PhotoDefautId
#   cr83b_codedefautc → Code defaut C
#     📋 Liste de choix (22 valeurs):
#       967350000 → P pix
#       967350001 → S cicatrice
#       967350002 → Q double ecaille
#       967350003 → G parasite sangsue
#       967350004 → M frisée crispéé
#       967350005 → W wrinkle
#       967350006 → V tâche blanche
#       967350007 → C coupure
#       967350008 → D nombril
#       967350009 → 0 creux blanc
#       967350010 → K bas de fleur
#       967350011 → 1 cloque
#       967350012 → 2 manque cites
#       967350013 → 6 arrêt de poisson
#       967350014 → Y gale
#       967350015 → N trou
#       967350016 → 12 naissance ecaille
#       967350017 → 8 pli de rivière
#       967350018 → 86 moisissure
#       967350019 → J coupure dérayage
#       967350020 → O graisse, gras
#       967350021 → 4 cratère
#   smallapp_AffectationLotCuve → Partie de sous-lot <> Cuve
#   smallapp_CuveLezard → Cuve (Lézard)
#   smallapp_LotAchat → Lot d'achat
#   smallapp_LotAchatTaille → Sous-lot d'achat
#
# Table: Commentaires (21 colonnes)
#   cr446_Cuve → Cuve (Crocodile)
#   cr446_ProgAval → Programme (Aval)
#   cr446_Programme → Programme (Amont)
#   cr446_codecommentaire → Code Commentaire
#   cr446_commentaire_AsyncOperations → Tâches système
#   cr446_commentaire_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_commentaire_DuplicateBaseRecord → Enregistrements dupliqués (cr446_commentaire_DuplicateBaseRecord)
#   cr446_commentaire_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_commentaire_DuplicateMatchingRecord)
#   cr446_commentaire_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_commentaire_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_commentaire_ProcessSession → Sessions de traitement
#   cr446_commentaire_SyncErrors → Erreurs de synchronisation
#   cr446_commentaireid → Commentaire
#   cr446_image → Image
#   cr446_imageid → cr446_ImageId
#   cr446_texte → Texte
#   smallapp_AffectationLotCuve → Partie de sous-lot <> Cuve
#   smallapp_CuveLezard → Cuve (Lézard)
#   smallapp_LotAchat → Lot d'achat
#   smallapp_LotAchatTaille → Sous-lot d'achat
#   smallapp_type → Type
#     📋 Liste de choix (3 valeurs):
#       1 → Classique
#       2 → Qualité
#       3 → Process
#
# Table: Programmes Aval (49 colonnes)
#   cr446_affectation_ProgAval_cr446_programmeaval → Affectations
#   cr446_casier → Casier
#     📋 Liste de choix (52 valeurs):
#       113790000 → A1
#       113790001 → A2
#       113790002 → A3
#       113790003 → A4
#       113790004 → A5
#       113790005 → B1
#       113790006 → B2
#       113790007 → B3
#       113790008 → B4
#       113790009 → B5
#       113790010 → C1
#       113790011 → C2
#       113790012 → C3
#       113790013 → C4
#       113790014 → C5
#       113790015 → D1
#       113790016 → D2
#       113790017 → D3
#       113790018 → D4
#       113790019 → D5
#       113790020 → E1
#       113790021 → E2
#       113790022 → E3
#       113790023 → E4
#       113790024 → E5
#       113790025 → F1
#       113790026 → F2
#       113790027 → F3
#       113790028 → F4
#       113790029 → F5
#       113790030 → G1
#       113790031 → G2
#       113790032 → G3
#       113790033 → G4
#       113790034 → G5
#       113790035 → H1
#       113790036 → H2
#       113790037 → H3
#       113790038 → H4
#       113790039 → H5
#       113790040 → I1
#       113790041 → I2
#       113790042 → I3
#       113790043 → I4
#       113790044 → I5
#       113790045 → Côté étagère A
#       113790046 → Côté étagère B
#       113790047 → Côté étagère C
#       113790048 → Chariot triage
#       113790049 → Chariot côté étagère A
#       113790050 → Derrière cadreuse 1 et 2
#       113790051 → Etagère tri
#   cr446_cdvliee → CDV liée
#   cr446_clientlivre → Client Livré
#   cr446_codearticle → Code Article
#   cr446_codecoloris → Code Coloris
#   cr446_codeespece → Code Espèce
#   cr446_codeetape → Code étape
#   cr446_codefinition → Code Finition
#   cr446_commentaire_ProgAval_cr446_programmeaval → Commentaires
#   cr446_cqfr_ProgAval_cr446_programmeaval → CQFR
#   cr446_cuve_ProgAval_cr446_programmeaval → Cuves Croco
#   cr446_datecommande → Date Commande
#   cr446_dateengagement → Date Engagement
#   cr446_decoupe → Découpe
#   cr446_defaut_ProgAval_cr446_programmeaval → Défauts
#   cr446_designation → Désignation
#   cr446_espece → Espèce
#   cr446_essai_ProgAval_cr446_programmeaval → Essais
#   cr446_etape → Etape
#   cr446_etat → Etat
#   cr446_libellearticle → Libellé Article
#   cr446_libellecoloris → Libellé Coloris
#   cr446_libellefinition → Libellé Finition
#   cr446_master → Master
#   cr446_ncommandeclient → N° Commande Client
#   cr446_poids → Poids
#   cr446_progid → ProgID
#   cr446_programmeaval_AsyncOperations → Tâches système
#   cr446_programmeaval_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_programmeaval_DuplicateBaseRecord → Enregistrements dupliqués (cr446_programmeaval_DuplicateBaseRecord)
#   cr446_programmeaval_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_programmeaval_DuplicateMatchingRecord)
#   cr446_programmeaval_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_programmeaval_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_programmeaval_ProcessSession → Sessions de traitement
#   cr446_programmeaval_SyncErrors → Erreurs de synchronisation
#   cr446_programmeavalid → Programme Aval
#   cr446_pxaaffecter → Px à affecter
#   cr446_pxnecessaires → Px nécessaires
#   cr446_pxrestantes → Px restantes
#   cr446_referencehermes → Référence Hermès
#   cr446_relance → Relance
#   cr446_resa → Résa
#     📋 Liste de choix (2 valeurs):
#       0 → No
#       1 → Yes
#   cr446_taillemax → Taille Max
#   cr446_taillemin → Taille min
#   cr446_typeof → Type OF
#   smallapp_casiercheck → Casier Check
#   smallapp_datecasier → Date Casier
#   smallapp_familleespece → Famille Espèce
#
# Table: Lots Achat (31 colonnes)
#   cr446_familleespece → Famille Espèce
#   cr446_quantitechoix1bc → Quantité Choix 1 BC
#   cr446_quantitechoix2bc → Quantité Choix 2 BC
#   cr446_quantitechoix3bc → Quantité Choix 3 BC
#   smallapp_affectationlotcuve_LotAchat_smallapp_lotachat → Affectation Lot-Cuves
#   smallapp_cr446_affectation_LotAchat_smallapp_lotachat → Affectations
#   smallapp_cr446_commentaire_LotAchat_smallapp_lotachat → Commentaires
#   smallapp_cr446_defaut_LotAchat_smallapp_lotachat → Défauts
#   smallapp_cr446_essai_LotAchat_smallapp_lotachat → Essais
#   smallapp_espece → Espèce
#     📋 Liste de choix (3 valeurs):
#       579940000 → Varanus Niloticus
#       579940001 → Varanus Salvatore SD
#       579940002 → Varanus Salvatore VN
#   smallapp_identifiant → Identifiant
#   smallapp_lotachat_AsyncOperations → Tâches système
#   smallapp_lotachat_BulkDeleteFailures → Échecs des suppressions en bloc
#   smallapp_lotachat_DuplicateBaseRecord → Enregistrements dupliqués (smallapp_lotachat_DuplicateBaseRecord)
#   smallapp_lotachat_DuplicateMatchingRecord → Enregistrements dupliqués (smallapp_lotachat_DuplicateMatchingRecord)
#   smallapp_lotachat_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   smallapp_lotachat_PrincipalObjectAttributeAccesses → Partage de champ
#   smallapp_lotachat_ProcessSession → Sessions de traitement
#   smallapp_lotachat_SyncErrors → Erreurs de synchronisation
#   smallapp_lotachatid → Lot Achat
#   smallapp_lotachattaille_LotAchat_smallapp_lotachat → Lots Achat Taille
#   smallapp_numerolot → Numéro Lot
#   smallapp_origine → Origine
#     📋 Liste de choix (5 valeurs):
#       579940000 → ABI
#       579940001 → BIZ
#       579940002 → VER
#       579940003 → VV
#       579940004 → YOU
#   smallapp_peaux_LotAchat_smallapp_lotachat → Peaux
#   smallapp_quantitebc → Quantité BC
#   smallapp_quantitechoix1 → Quantité Choix 1 FC
#   smallapp_quantitechoix2 → Quantité Choix 2 FC
#   smallapp_quantitechoix3 → Quantité Choix 3 FC
#   smallapp_quantitefc → Quantité FC
#   smallapp_quantiterecue → Quantité Reçue
#   smallapp_quantiterejetee → Quantité Rejetée
#
# Table: Lots Achat Taille (30 colonnes)
#   cr446_espece → Espèce
#   cr446_familleespece → Famille Espèce
#   cr446_origine → Origine
#   cr446_quantitechoix1bc → Quantité Choix 1 BC
#   cr446_quantitechoix2bc → Quantité Choix 2 BC
#   cr446_quantitechoix3bc → Quantité Choix 3 BC
#   cr446_quantiterejetee → Quantité Rejetée
#   smallapp_LotAchat → Lot Achat
#   smallapp_affectationlotcuve_LotAchatTaille_smallapp_lotachattaille → Affectation Lot-Cuves
#   smallapp_cr446_affectation_LotAchatTaille_smallapp_lotachattaille → Affectations
#   smallapp_cr446_commentaire_LotAchatTaille_smallapp_lotachattaille → Commentaires
#   smallapp_cr446_defaut_LotAchatTaille_smallapp_lotachattaille → Défauts
#   smallapp_cr446_essai_LotAchatTaille_smallapp_lotachattaille → Essais
#   smallapp_identifiant → Identifiant
#   smallapp_lotachattaille_AsyncOperations → Tâches système
#   smallapp_lotachattaille_BulkDeleteFailures → Échecs des suppressions en bloc
#   smallapp_lotachattaille_DuplicateBaseRecord → Enregistrements dupliqués (smallapp_lotachattaille_DuplicateBaseRecord)
#   smallapp_lotachattaille_DuplicateMatchingRecord → Enregistrements dupliqués (smallapp_lotachattaille_DuplicateMatchingRecord)
#   smallapp_lotachattaille_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   smallapp_lotachattaille_PrincipalObjectAttributeAccesses → Partage de champ
#   smallapp_lotachattaille_ProcessSession → Sessions de traitement
#   smallapp_lotachattaille_SyncErrors → Erreurs de synchronisation
#   smallapp_lotachattailleid → Lot Achat Taille
#   smallapp_peaux_LotAchatTaille_smallapp_lotachattaille → Peaux
#   smallapp_quantitebc → Quantité BC
#   smallapp_quantitechoix1 → Quantité Choix 1 FC
#   smallapp_quantitechoix2 → Quantité Choix 2 FC
#   smallapp_quantitechoix3 → Quantité Choix 3 FC
#   smallapp_quantitefc → Quantité FC
#   smallapp_taille → Taille
#     📋 Liste de choix (22 valeurs):
#       579940000 → 19-
#       579940001 → 20
#       579940002 → 21
#       579940003 → 22
#       579940004 → 23
#       579940005 → 24
#       579940006 → 25
#       579940007 → 26
#       579940008 → 27
#       579940009 → 28
#       579940010 → 29
#       579940011 → 30
#       579940012 → 31
#       579940013 → 32
#       579940014 → 33
#       579940015 → 34
#       579940016 → 35
#       579940017 → 36
#       579940018 → 37
#       579940019 → 38
#       579940020 → 39
#       579940021 → 40+
#
# Table: Peaux (22 colonnes)
#   smallapp_AffectationLotCuve → Affectation Lot-Cuve
#   smallapp_Cuve → Cuve Lézard
#   smallapp_LotAchat → Lot Achat
#   smallapp_LotAchatTaille → Lot Achat Taille
#   smallapp_choix → Choix
#   smallapp_choixcroute → Choix Croute
#   smallapp_choixhermes → Choix Hermès
#   smallapp_decoupe → Découpe
#   smallapp_emplacementcroute → Emplacement Croute
#   smallapp_modelecroute → Modèle Croute
#     📋 Liste de choix (56 valeurs):
#       579940000 → AZAP INTEGRAL
#       579940001 → BANGLE OLYMPE
#       579940002 → BEARN COMPACT
#       579940003 → BIRKIN 25
#       579940004 → BIRKIN 30
#       579940005 → BIRKIN SELLIER 20
#       579940006 → BIRKIN SELLIER 20 SERTI
#       579940007 → BK 25 TOUCH
#       579940008 → BOLIDE MINI 1923
#       579940009 → BOLIDE TOUCH
#       579940010 → BOUCLE OREILLES OLYMPE
#       579940011 → CALVI
#       579940012 → CALVI DUO
#       579940013 → CHAINE D'ANCRE COMPACT
#       579940014 → COFFRET AMALTHEE PM
#       579940015 → COLLIER DE CHIEN
#       579940016 → COLLIER DE CHIEN 24
#       579940017 → CONSTANCE 1-24
#       579940018 → CONSTANCE III MINI
#       579940019 → CONSTANCE III MINI MIROIR
#       579940020 → CONSTANCE MICRO
#       579940021 → CONSTANCE SLIM COMPACT
#       579940022 → CONSTANCE TO GO
#       579940023 → ETUI MONTRE GM
#       579940024 → ETUI MONTRE PM
#       579940025 → H CHAUSSURE GLAMOUR FULL
#       579940026 → HACABOX
#       579940027 → HERMES GANTS
#       579940028 → HERMES MINUIT AU FAUBOURG 20
#       579940029 → ILIADE PORTE-CARTES
#       579940030 → JIGE ELAN TOUCH
#       579940031 → JOY 105, FULL MODELE
#       579940032 → KELLY DANSE II
#       579940033 → KELLY DEPECHES 25
#       579940034 → KELLY DOUBLE TOUR
#       579940035 → KELLY ELAN
#       579940036 → KELLY FESTIVAL
#       579940037 → KELLY II SELLIER 25
#       579940038 → KELLY II SELLIER 25 KELLYOPTIC
#       579940039 → KELLY II SELLIER 28
#       579940040 → KELLY II SELLIER MINI
#       579940041 → KELLY II SELLIER MINI TOUCH
#       579940042 → KELLY MESSENGER PM
#       579940043 → KELLY MINI
#       579940044 → KELLY TO GO
#       579940045 → MAH-JONG
#       579940046 → OASIS FEMME H PUNTINA FILETTO
#       579940047 → PICOTIN LOCL MICRO
#       579940048 → POCHETTE KELLY MINI
#       579940049 → ROULIS MINI
#       579940050 → ROULIS SLIM COMPACT
#       579940051 → SAC A DEPECHES 21
#       579940052 → SAC A DEPECHES 24
#       579940053 → TOUCH 3 KELLY RET 25
#       579940054 → TWIST PM
#       579940055 → VERROU CHAINE MINI
#   smallapp_peaux_AsyncOperations → Tâches système
#   smallapp_peaux_BulkDeleteFailures → Échecs des suppressions en bloc
#   smallapp_peaux_DuplicateBaseRecord → Enregistrements dupliqués (smallapp_peaux_DuplicateBaseRecord)
#   smallapp_peaux_DuplicateMatchingRecord → Enregistrements dupliqués (smallapp_peaux_DuplicateMatchingRecord)
#   smallapp_peaux_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   smallapp_peaux_PrincipalObjectAttributeAccesses → Partage de champ
#   smallapp_peaux_ProcessSession → Sessions de traitement
#   smallapp_peaux_SyncErrors → Erreurs de synchronisation
#   smallapp_peauxid → Peaux
#   smallapp_rfid → RFID
#   smallapp_taille → Taille
#   smallapp_taillecroute → Taille Croute
#
# Table: CQFR (38 colonnes)
#   cr446_Cuve → Cuve (Crocodile)
#   cr446_ProgAval → Programme (Aval)
#   cr446_brillance → Brillance %
#   cr446_commentairequalite → Commentaire Qualité
#   cr446_cqfr_AsyncOperations → Tâches système
#   cr446_cqfr_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_cqfr_DuplicateBaseRecord → Enregistrements dupliqués (cr446_cqfr_DuplicateBaseRecord)
#   cr446_cqfr_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_cqfr_DuplicateMatchingRecord)
#   cr446_cqfr_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_cqfr_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_cqfr_ProcessSession → Sessions de traitement
#   cr446_cqfr_SyncErrors → Erreurs de synchronisation
#   cr446_cqfrid → CQFR
#   cr446_espece → Espèce
#   cr446_homogeneite → Homogénéité %
#   cr446_libellearticle → Libellé Article
#   cr446_libellecoloris → Libellé Coloris
#   cr446_libellefinition → Libellé Finition
#   cr446_numero → Numero
#   cr446_quantite → Quantité
#   cr446_souplesse → Souplesse %
#   cr446_spectro → Spectro
#   cr446_taillemax → Taille Max
#   cr446_taillemin → Taille Min
#   cr446_touche → Touché %
#   smallapp_familleespece → Famille Espèce
#   smallapp_modele → Modèle
#   smallapp_quantitelivree → Quantité livrée
#   smallapp_quantiterebutrejet → Quantité rebut/rejet
#   smallapp_resultatveslichumidecuir → Résultat Veslic Humide Cuir
#     📋 Liste de choix (12 valeurs):
#       579940000 → 0
#       579940001 → 0-1
#       579940002 → 1
#       579940003 → 1-2
#       579940004 → 2
#       579940005 → 2-3
#       579940006 → 3
#       579940007 → 3-4
#       579940008 → 4
#       579940009 → 4-5
#       579940010 → 5
#       579940011 → N/A
#   smallapp_resultatveslichumidefeutre → Résultat Veslic Humide Feutre
#   smallapp_resultatveslicseccuir → Résultat Veslic Sec Cuir
#   smallapp_resultatveslicsecfeutre → Résultat Veslic Sec Feutre
#   smallapp_testpvc → Test PVC
#   smallapp_testscotch → Test Scotch
#   smallapp_uv12h → UV12h
#   smallapp_uv24h → UV24h
#   smallapp_uv6h → UV6H
#
# Table: Affectations Lot-Cuve (25 colonnes)
#   cr446_espece → Espèce
#   smallapp_CuveLezard → Cuve Lézard
#   smallapp_LotAchat → Lot Achat
#   smallapp_LotAchatTaille → Lot Achat Taille
#   smallapp_affectationlotcuve_AsyncOperations → Tâches système
#   smallapp_affectationlotcuve_BulkDeleteFailures → Échecs des suppressions en bloc
#   smallapp_affectationlotcuve_DuplicateBaseRecord → Enregistrements dupliqués (smallapp_affectationlotcuve_DuplicateBaseRecord)
#   smallapp_affectationlotcuve_DuplicateMatchingRecord → Enregistrements dupliqués (smallapp_affectationlotcuve_DuplicateMatchingRecord)
#   smallapp_affectationlotcuve_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   smallapp_affectationlotcuve_PrincipalObjectAttributeAccesses → Partage de champ
#   smallapp_affectationlotcuve_ProcessSession → Sessions de traitement
#   smallapp_affectationlotcuve_SyncErrors → Erreurs de synchronisation
#   smallapp_affectationlotcuveid → Affectation Lot-Cuve
#   smallapp_cr446_affectation_AffectationLotCuve_smallapp_affectationlotcuve → Affectations
#   smallapp_cr446_commentaire_AffectationLotCuve_smallapp_affectationlotcuve → Commentaires
#   smallapp_cr446_defaut_AffectationLotCuve_smallapp_affectationlotcuve → Défauts
#   smallapp_cr446_essai_AffectationLotCuve_smallapp_affectationlotcuve → Essais
#   smallapp_identifiant → Identifiant
#   smallapp_peaux_AffectationLotCuve_smallapp_affectationlotcuve → Peaux
#   smallapp_quantitebc → Quantité BC
#   smallapp_quantitechoix1 → Quantité Choix 1
#   smallapp_quantitechoix2 → Quantité Choix 2
#   smallapp_quantitechoix3 → Quantité Choix 3
#   smallapp_quantitefc → Quantité FC
#   smallapp_quantitetotale → Quantité Totale
#
# Table: Cuves Lézard (33 colonnes)
#   smallapp_affectationlotcuve_CuveLezard_smallapp_cuvelezard → Affectation Lot-Cuves
#   smallapp_cr446_affectation_CuveLezard_smallapp_cuvelezard → Affectations
#   smallapp_cr446_commentaire_CuveLezard_smallapp_cuvelezard → Commentaires
#   smallapp_cr446_defaut_CuveLezard_smallapp_cuvelezard → Défauts
#   smallapp_cr446_essai_CuveLezard_smallapp_cuvelezard → Essais
#   smallapp_cuvelezard_AsyncOperations → Tâches système
#   smallapp_cuvelezard_BulkDeleteFailures → Échecs des suppressions en bloc
#   smallapp_cuvelezard_DuplicateBaseRecord → Enregistrements dupliqués (smallapp_cuvelezard_DuplicateBaseRecord)
#   smallapp_cuvelezard_DuplicateMatchingRecord → Enregistrements dupliqués (smallapp_cuvelezard_DuplicateMatchingRecord)
#   smallapp_cuvelezard_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   smallapp_cuvelezard_PrincipalObjectAttributeAccesses → Partage de champ
#   smallapp_cuvelezard_ProcessSession → Sessions de traitement
#   smallapp_cuvelezard_SyncErrors → Erreurs de synchronisation
#   smallapp_cuvelezardid → Cuve Lézard
#   smallapp_datemae → Date MAE
#   smallapp_datetri → Date Tri
#   smallapp_espece → Espèce
#   smallapp_etape → Etape
#   smallapp_etapeauto → Etape Auto
#   smallapp_etat → Etat
#   smallapp_famille → Famille
#   smallapp_foulonretannage → Foulon Retannage
#   smallapp_foulonriviere → Foulon Rivière
#   smallapp_foulontannage → Foulon Tannage
#   smallapp_numero → Numéro
#   smallapp_peaux_Cuve_smallapp_cuvelezard → Peaux
#   smallapp_poids → Poids
#   smallapp_quantitebc → Quantité BC
#   smallapp_quantitechoix1 → Quantité Choix 1
#   smallapp_quantitechoix2 → Quantité Choix 2
#   smallapp_quantitechoix3 → Quantité Choix 3
#   smallapp_quantitefc → Quantité FC
#   smallapp_quantitemae → Quantité MAE
#
# === OPTIONS D'EXPORT ===
# 1. Mermaid (pour diagramme ER)
# 2. JSON structuré (complet)
# 3. CSV des tables et colonnes
# 4. XML
# 5. Tous les formats
# ✅ Fichier 'architecture_mermaid.md' généré
# ✅ Fichier 'architecture_complete.json' généré
# ✅ Fichier 'tables_colonnes.csv' généré
# ✅ Fichier 'architecture_drawio.xml' généré
# Nombre de tables:  13
# Nombre total de colonnes:  410
#
# 🎉 Extraction terminée !

# %%
import json
import re
from collections import defaultdict

# Charger le fichier DataSources.json
with open('DataSources.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Accéder à la liste des DataSources
data_sources = data["DataSources"]

# Tables à exclure
excluded_tables = ["Divisions", "Utilisateurs"]

# Colonnes systèmes à exclure
excluded_columns = {
    "utcconversiontimezonecode", "_ownerid_value", "statuscode", "statecode",
    "modifiedonbehalfby", "createdonbehalfby", "owninguser", "timezoneruleversionnumber",
    "owningbusinessunit", "modifiedon", "modifiedby", "versionnumber",
    "overriddencreatedon", "createdby", "importsequencenumber", "owningteam", "createdon"
}

# Dictionnaire pour stocker les tables et leurs colonnes
tables = {}

# Dictionnaire pour les Option Sets
option_sets = {}
option_sets_by_column = {}  # Pour lier rapidement colonne -> choix
option_set_references = {}   # Pour les liaisons entre tables

# Extraire d'abord tous les Option Sets avec leurs références
for ds in data_sources:
    if ds.get("Type") == "OptionSetInfo":
        option_set_name = ds.get("Name")
        related_entity = ds.get("RelatedEntityName")
        related_column = ds.get("RelatedColumnInvariantName")
        option_mapping = ds.get("OptionSetInfoNameMapping", {})
        option_references = ds.get("OptionSetReference", {})
        
        if option_set_name and related_entity and related_column:
            key = f"{related_entity}.{related_column}"
            option_sets_by_column[key] = option_mapping
            
            # Extraire les références vers d'autres tables
            references = []
            if option_references:
                for ref_key, ref_value in option_references.items():
                    if isinstance(ref_value, dict):
                        ref_entity = ref_value.get("OptionSetReferenceEntityName")
                        ref_column = ref_value.get("OptionSetReferenceColumnName")
                        if ref_entity and ref_column:
                            references.append({
                                "entity": ref_entity,
                                "column": ref_column
                            })
            
            if references:
                option_set_references[key] = references

# Parcourir les DataSources pour les tables
for ds in data_sources:
    if ds.get("Type") == "NativeCDSDataSourceInfo":
        table_name = ds.get("Name") or ds.get("LogicalName") or ds.get("EntitySetName")
        if not table_name or table_name in excluded_tables:
            continue
            
        columns_detail = {}
        name_mapping = ds.get("NativeCDSDataSourceInfoNameMapping", {})
        
        if name_mapping:
            for technical_name, display_name in name_mapping.items():
                if technical_name in excluded_columns:
                    continue
                columns_detail[technical_name] = display_name
        
        tables[table_name] = columns_detail

# Fonction pour générer l'export HTML
def generate_html_export(tables, option_sets_by_column, option_set_references):
    html_lines = [
        '<!DOCTYPE html>',
        '<html lang="fr">',
        '<head>',
        '<meta charset="UTF-8">',
        '<meta name="viewport" content="width=device-width, initial-scale=1.0">',
        '<title>Architecture Power Apps</title>',
        '<style>',
        'body { font-family: Arial, sans-serif; margin: 20px; }',
        'h1 { color: #2c3e50; }',
        'h2 { color: #34495e; border-bottom: 2px solid #3498db; padding-bottom: 5px; }',
        'h3 { color: #4a4a4a; }',
        '.table-container { margin-bottom: 30px; }',
        '.columns-table { border-collapse: collapse; width: 100%; margin: 10px 0; }',
        '.columns-table th, .columns-table td { border: 1px solid #ddd; padding: 8px; text-align: left; }',
        '.columns-table th { background-color: #f2f2f2; }',
        '.choices-table { border-collapse: collapse; width: 80%; margin: 10px 0 20px 20px; }',
        '.choices-table th, .choices-table td { border: 1px solid #eee; padding: 6px; text-align: left; }',
        '.choices-table th { background-color: #e8f4f8; }',
        '.choice-link { color: #2980b9; text-decoration: none; }',
        '.choice-link:hover { text-decoration: underline; }',
        '.references { margin: 10px 0; padding: 10px; background-color: #fff3cd; border-left: 4px solid #ffc107; }',
        '.connection-line { border-left: 2px dashed #95a5a6; margin-left: 20px; padding-left: 15px; }',
        '</style>',
        '</head>',
        '<body>',
        '<h1>Architecture Power Apps</h1>'
    ]
    
    # Pour chaque table
    for table, cols in sorted(tables.items()):
        html_lines.append(f'<div class="table-container">')
        html_lines.append(f'<h2>Table: {table} ({len(cols)} colonnes)</h2>')
        
        # Tableau des colonnes
        html_lines.append('<table class="columns-table">')
        html_lines.append('<thead>')
        html_lines.append('<tr><th>Nom Technique</th><th>Nom Affiché</th><th>Liste de Choix</th><th>Références</th></tr>')
        html_lines.append('</thead>')
        html_lines.append('<tbody>')
        
        for tech_name, display_name in sorted(cols.items()):
            option_key = f"{table}.{tech_name}"
            
            # Liste de choix
            choices_html = ""
            if option_key in option_sets_by_column:
                options = option_sets_by_column[option_key]
                choices_html = f'<a href="#choice_{table}_{tech_name}" class="choice-link">Voir {len(options)} choix</a>'
            
            # Références
            references_html = ""
            if option_key in option_set_references:
                refs = option_set_references[option_key]
                ref_links = []
                for ref in refs:
                    ref_links.append(f'{ref["entity"]}.{ref["column"]}')
                references_html = "<br>".join(ref_links)
            
            html_lines.append(f'<tr>')
            html_lines.append(f'<td>{tech_name}</td>')
            html_lines.append(f'<td>{display_name}</td>')
            html_lines.append(f'<td>{choices_html}</td>')
            html_lines.append(f'<td>{references_html}</td>')
            html_lines.append(f'</tr>')
        
        html_lines.append('</tbody>')
        html_lines.append('</table>')
        
        # Tableaux des listes de choix
        for tech_name, display_name in sorted(cols.items()):
            option_key = f"{table}.{tech_name}"
            if option_key in option_sets_by_column:
                options = option_sets_by_column[option_key]
                html_lines.append(f'<div id="choice_{table}_{tech_name}" class="connection-line">')
                html_lines.append(f'<h3>Liste de choix pour {display_name} ({tech_name})</h3>')
                html_lines.append('<table class="choices-table">')
                html_lines.append('<thead><tr><th>Code</th><th>Valeur</th></tr></thead>')
                html_lines.append('<tbody>')
                
                for key, value in sorted(options.items()):
                    html_lines.append(f'<tr><td>{key}</td><td>{value}</td></tr>')
                
                html_lines.append('</tbody>')
                html_lines.append('</table>')
                html_lines.append('</div>')
        
        html_lines.append('</div>')
    
    # Section des références croisées
    html_lines.append('<h2>Références Croisées</h2>')
    html_lines.append('<div class="references">')
    
    if option_set_references:
        for option_key, references in option_set_references.items():
            table_name, col_name = option_key.split('.', 1)
            html_lines.append(f'<p><strong>{table_name}.{col_name}</strong> est référencé par:')
            for ref in references:
                html_lines.append(f'<br>&nbsp;&nbsp;→ {ref["entity"]}.{ref["column"]}')
    else:
        html_lines.append('<p>Aucune référence croisée trouvée.</p>')
    
    html_lines.append('</div>')
    
    html_lines.append('</body>')
    html_lines.append('</html>')
    
    with open('architecture_powerapps.html', 'w', encoding='utf-8') as f:
        f.write('\n'.join(html_lines))
    
    print("✅ Fichier 'architecture_powerapps.html' généré")

# Fonction pour nettoyer les noms pour Mermaid
def clean_mermaid_name(name):
    # Remplacer les caractères problématiques
    cleaned = re.sub(r'[^a-zA-Z0-9_]', '_', name)
    # S'assurer qu'il ne commence pas par un chiffre
    if cleaned and cleaned[0].isdigit():
        cleaned = "attr_" + cleaned
    return cleaned if cleaned else "unnamed_attr"

# Fonction pour générer le diagramme Mermaid avec la bonne syntaxe
def generate_mermaid_graph(tables):
    mermaid_lines = ["```mermaid", "erDiagram"]
    
    # Ajouter les entités avec la syntaxe correcte
    for table, cols in tables.items():
        clean_table = clean_mermaid_name(table)
        
        mermaid_lines.append(f'    {clean_table} {{')
        
        # Ajouter les attributs (limité à 10 pour la lisibilité)
        for i, (tech_name, display_name) in enumerate(list(cols.items())[:10]):
            clean_attr = clean_mermaid_name(tech_name)
            # Syntaxe correcte : type nom
            mermaid_lines.append(f'        string {clean_attr} "{display_name}"')
        
        if len(cols) > 10:
            mermaid_lines.append(f'        string other "... et {len(cols) - 10} autres colonnes"')
            
        mermaid_lines.append('    }')
    
    # Ajouter quelques relations basiques
    for table, cols in tables.items():
        clean_table = clean_mermaid_name(table)
        for col_name in cols.keys():
            if col_name.endswith('id') and col_name != 'id':
                target_table = col_name[:-2]  # Enlever 'id'
                if target_table in tables:
                    clean_target = clean_mermaid_name(target_table)
                    clean_col = clean_mermaid_name(col_name)
                    mermaid_lines.append(f'    {clean_target} ||--o{{ {clean_table} : "{col_name}"')
    
    mermaid_lines.append("```")
    return "\n".join(mermaid_lines)

# Export vers format JSON structuré
def generate_structured_json():
    architecture = {
        "tables": {},
        "relationships": [],
        "option_sets": {},
        "option_set_references": option_set_references
    }
    
    # Tables et colonnes
    for table, cols in tables.items():
        architecture["tables"][table] = {
            "columns": cols,
            "option_sets": {}
        }
        
        # Ajouter les option sets pour cette table
        for col_name in cols.keys():
            option_key = f"{table}.{col_name}"
            if option_key in option_sets_by_column:
                architecture["tables"][table]["option_sets"][col_name] = option_sets_by_column[option_key]
    
    # Relations basiques
    for table, cols in tables.items():
        for col_name in cols.keys():
            if col_name.endswith('id') and col_name != 'id':
                target_table = col_name[:-2]
                if target_table in tables:
                    architecture["relationships"].append({
                        "from_table": target_table,
                        "to_table": table,
                        "column": col_name,
                        "type": "lookup"
                    })
    
    return architecture

# Export pour Drawio
def clean_xml_text(text):
    """Nettoyer le texte pour XML"""
    if not text:
        return ""
    return text.replace("&", "&amp;").replace("<", "&lt;").replace(">", "&gt;").replace('"', "&quot;")

def generate_drawio_complete(tables, option_sets_by_column, option_set_references):
    xml_lines = [
        '<?xml version="1.0" encoding="UTF-8"?>',
        '<mxfile host="app.diagrams.net">',
        '<diagram name="Architecture Power Apps" id="architecture-powerapps">',
        '<mxGraphModel dx="1426" dy="745" grid="1" gridSize="10" guides="1" tooltips="1" connect="1" arrows="1" fold="1" page="1" pageScale="1" pageWidth="850" pageHeight="1100" background="#ffffff" math="0" shadow="0">'
    ]
    
    xml_lines.append('<root>')
    xml_lines.append('<mxCell id="0"/>')
    xml_lines.append('<mxCell id="1" parent="0"/>')
    
    # Générer les tables avec toutes les colonnes
    x_pos = 20
    y_pos = 20
    table_positions = {}  # Pour les relations
    
    # Premier passage : Tables principales
    for i, (table, cols) in enumerate(tables.items()):
        table_id = f"table_{i}"
        table_positions[table] = {
            'id': table_id,
            'x': x_pos + (i % 4) * 350,  # 4 colonnes max
            'y': y_pos + (i // 4) * 600   # Nouvelle ligne tous les 4
        }
        
        # Hauteur calculée selon le nombre de colonnes (sans cellule vide)
        table_height = 30 + len(cols) * 26  # StartSize 30 + colonnes * 26
        
        # Table swimlane
        xml_lines.append(f'<mxCell id="{table_id}" value="{clean_xml_text(table)}" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=30;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;swimlaneFillColor=#ffffff;fillColor=#e3f2fd;strokeColor=#90A4AE;" vertex="1" parent="1">')
        xml_lines.append(f'<mxGeometry x="{table_positions[table]["x"]}" y="{table_positions[table]["y"]}" width="320" height="{table_height}" as="geometry"/>')
        xml_lines.append('</mxCell>')
        
        # Ajouter les colonnes (toutes) - CORRECTION : Pas de cellule vide à la fin
        current_y = 30
        for j, (tech_name, display_name) in enumerate(cols.items()):
            attr_id = f"{table_id}_attr_{j}"
            display_text = display_name if display_name else tech_name
            
            # Vérifier s'il y a une liste de choix
            option_key = f"{table}.{tech_name}"
            if option_key in option_sets_by_column:
                # Ajouter un indicateur visuel
                display_text = f"📋 {display_name}"
            
            # Style différent pour les colonnes avec listes de choix
            style = "text;strokeColor=none;fillColor=none;align=left;verticalAlign=middle;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;"
            if option_key in option_sets_by_column:
                style = "text;strokeColor=none;fillColor=#fff3e0;align=left;verticalAlign=middle;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;"
            
            xml_lines.append(f'<mxCell id="{attr_id}" value="{clean_xml_text(display_text)}" style="{style}" vertex="1" parent="{table_id}">')
            xml_lines.append(f'<mxGeometry y="{current_y}" width="320" height="26" as="geometry"/>')
            xml_lines.append('</mxCell>')
            
            current_y += 26
        # PAS DE CELLULE VIDE À LA FIN
    
    # Deuxième passage : Tables de choix (toutes)
    choice_table_id = 1000
    choice_positions = {}
    
    for table, cols in tables.items():
        table_info = table_positions.get(table)
        if not table_info:
            continue
            
        for tech_name, display_name in cols.items():
            option_key = f"{table}.{tech_name}"
            if option_key in option_sets_by_column:
                options = option_sets_by_column[option_key]
                
                # Créer une table de choix
                choice_id = f"choice_{choice_table_id}"
                choice_table_id += 1
                
                # Position à droite de la table principale
                choice_x = table_info['x'] + 370
                choice_y = table_info['y'] + 50 + (choice_table_id % 15) * 35
                
                choice_positions[option_key] = {
                    'id': choice_id,
                    'x': choice_x,
                    'y': choice_y
                }
                
                # Hauteur selon le nombre d'options (toutes) - CORRECTION : Pas de cellule vide
                choice_height = 30 + len(options) * 20  # StartSize 30 + options * 20
                
                # Table de choix
                xml_lines.append(f'<mxCell id="{choice_id}" value="{clean_xml_text(display_name)} [Choix]" style="swimlane;fontStyle=1;align=center;verticalAlign=top;childLayout=stackLayout;horizontal=1;startSize=30;horizontalStack=0;resizeParent=1;resizeParentMax=0;resizeLast=0;collapsible=1;marginBottom=0;swimlaneFillColor=#ffffff;fillColor=#f3e5f5;strokeColor=#AB47BC;" vertex="1" parent="1">')
                xml_lines.append(f'<mxGeometry x="{choice_x}" y="{choice_y}" width="240" height="{choice_height}" as="geometry"/>')
                xml_lines.append('</mxCell>')
                
                # Ajouter les options (toutes) - AMÉLIORATION : Tri par ordre croissant
                current_y = 30
                # CORRECTION : Trier les options par clé (ordre croissant)
                sorted_options = sorted(options.items(), key=lambda x: x[0])
                for k, (option_key_val, option_value) in enumerate(sorted_options):
                    option_attr_id = f"{choice_id}_option_{k}"
                    # Construction du texte avec séparation
                    option_display_text = f"{option_key_val} → {option_value}"
                    xml_lines.append(f'<mxCell id="{option_attr_id}" value="{clean_xml_text(option_display_text)}" style="text;strokeColor=none;fillColor=none;align=left;verticalAlign=middle;spacingLeft=4;spacingRight=4;overflow=hidden;rotatable=0;points=[[0,0.5],[1,0.5]];portConstraint=eastwest;fontSize=9;" vertex="1" parent="{choice_id}">')
                    xml_lines.append(f'<mxGeometry y="{current_y}" width="240" height="20" as="geometry"/>')
                    xml_lines.append('</mxCell>')
                    current_y += 20
                # PAS DE CELLULE VIDE À LA FIN
    
    # Troisième passage : Relations
    
    # 1. Relations entre colonnes et tables de choix (toutes)
    edge_id = 5000
    for table, cols in tables.items():
        table_info = table_positions.get(table)
        if not table_info:
            continue
            
        for tech_name, display_name in cols.items():
            option_key = f"{table}.{tech_name}"
            if option_key in option_sets_by_column and option_key in choice_positions:
                # Trouver l'ID de la colonne
                table_id = table_info['id']
                # Trouver la position de la colonne
                try:
                    col_index = list(cols.keys()).index(tech_name)
                    attr_id = f"{table_id}_attr_{col_index}"
                    
                    choice_info = choice_positions[option_key]
                    
                    # Créer la relation
                    source_cell = attr_id
                    target_cell = choice_info['id']
                    xml_lines.append(f'<mxCell id="edge_{edge_id}" style="edgeStyle=orthogonalEdgeStyle;rounded=0;orthogonalLoop=1;jettySize=auto;html=1;entryX=0;entryY=0.5;startArrow=none;endArrow=block;endFill=1;strokeColor=#AB47BC;strokeWidth=1;fontSize=9;" edge="1" parent="1" source="{source_cell}" target="{target_cell}">')
                    xml_lines.append('<mxGeometry relative="1" as="geometry"/>')
                    xml_lines.append('</mxCell>')
                    edge_id += 1
                except (ValueError, IndexError):
                    continue
    
    # 2. Relations entre tables (colonnes se terminant par 'id') (toutes)
    for table, cols in tables.items():
        table_info = table_positions.get(table)
        if not table_info:
            continue
        table_id = table_info['id']
        
        for col_name in cols.keys():
            if col_name.endswith('id') and col_name != 'id':
                target_table = col_name[:-2]  # Enlever 'id'
                if target_table in table_positions:
                    target_info = table_positions[target_table]
                    target_id = target_info['id']
                    
                    # Trouver l'ID de la colonne source
                    try:
                        col_index = list(cols.keys()).index(col_name)
                        source_attr_id = f"{table_id}_attr_{col_index}"
                        
                        # Créer la relation
                        source_cell = source_attr_id
                        target_cell = target_id
                        edge_label = clean_xml_text(col_name)
                        xml_lines.append(f'<mxCell id="edge_{edge_id}" value="{edge_label}" style="edgeStyle=entityRelationEdgeStyle;html=1;endArrow=ERoneToMany;entryX=0;entryY=0.5;strokeColor=#2196F3;strokeWidth=2;fontSize=10;" edge="1" parent="1" source="{source_cell}" target="{target_cell}">')
                        xml_lines.append('<mxGeometry width="100" height="100" relative="1" as="geometry">')
                        xml_lines.append('<mxPoint x="0" y="0" as="sourcePoint"/>')
                        xml_lines.append('<mxPoint x="100" y="100" as="targetPoint"/>')
                        xml_lines.append('</mxGeometry>')
                        xml_lines.append('</mxCell>')
                        edge_id += 1
                    except (ValueError, IndexError):
                        continue
    
    # 3. Relations de références croisées (option sets) (toutes)
    for option_key, references in option_set_references.items():
        if option_key in choice_positions:
            source_choice = choice_positions[option_key]
            source_id = source_choice['id']
            
            for ref in references:
                ref_table = ref['entity']
                ref_column = ref['column']
                if ref_table in table_positions:
                    target_table = table_positions[ref_table]
                    target_table_id = target_table['id']
                    
                    # Trouver l'ID de la colonne cible
                    if ref_table in tables and ref_column in tables[ref_table]:
                        try:
                            col_index = list(tables[ref_table].keys()).index(ref_column)
                            target_attr_id = f"{target_table_id}_attr_{col_index}"
                            
                            # Créer la relation
                            source_cell = source_id
                            target_cell = target_attr_id
                            xml_lines.append(f'<mxCell id="edge_{edge_id}" value="Référence" style="edgeStyle=orthogonalEdgeStyle;html=1;endArrow=block;endSize=8;dashed=1;strokeColor=#FF9800;strokeWidth=1;fontSize=9;jumpStyle=arc;fillColor=#0050ef;" edge="1" parent="1" source="{source_cell}" target="{target_cell}">')
                            xml_lines.append('<mxGeometry width="100" height="100" relative="1" as="geometry">')
                            xml_lines.append('<mxPoint x="0" y="0" as="sourcePoint"/>')
                            xml_lines.append('<mxPoint x="100" y="100" as="targetPoint"/>')
                            xml_lines.append('</mxGeometry>')
                            xml_lines.append('</mxCell>')
                            edge_id += 1
                        except (ValueError, IndexError):
                            continue
    
    xml_lines.append('</root>')
    xml_lines.append('</mxGraphModel>')
    xml_lines.append('</diagram>')
    xml_lines.append('</mxfile>')
    
    with open('architecture_complete.drawio', 'w', encoding='utf-8') as f:
        f.write('\n'.join(xml_lines))
    
    print("✅ Fichier 'architecture_complete.drawio' généré")
    print("Nombre de tables: ", len(tables))
    total_cols = sum(len(cols) for cols in tables.values())
    print("Nombre total de colonnes: ", total_cols)
    
    # Compter les tables de choix générées
    choice_tables_count = len([k for k in option_sets_by_column.keys() if k in option_sets_by_column])
    print("Nombre de tables de choix générées: ", choice_tables_count)


# Afficher les tables avec leurs colonnes et listes de choix
print("=== LISTE DES TABLES AVEC COLONNES ET LISTES DE CHOIX ===")

for table, cols in tables.items():
    print(f"\nTable: {table} ({len(cols)} colonnes)")
    for tech_name, display_name in sorted(cols.items()):
        print(f"  {tech_name} → {display_name}")
        
        # Vérifier s'il y a une liste de choix pour cette colonne
        option_key = f"{table}.{tech_name}"
        if option_key in option_sets_by_column:
            options = option_sets_by_column[option_key]
            print(f"    📋 Liste de choix ({len(options)} valeurs):")
            for key, value in sorted(options.items()):
                print(f"      {key} → {value}")
        
        # Vérifier s'il y a des références
        if option_key in option_set_references:
            refs = option_set_references[option_key]
            print(f"    🔗 Référencé par:")
            for ref in refs:
                print(f"      → {ref['entity']}.{ref['column']}")

# Proposer les exports
print(f"\n=== OPTIONS D'EXPORT ===")
print("1. Mermaid (pour diagramme ER)")
print("2. JSON structuré (complet)")
print("3. CSV des tables et colonnes")
print("4. XML Draw.io")
print("5. HTML (complet avec références)")
print("6. Tous les formats")

choice = input("Quel format voulez-vous générer ? (1/2/3/4/5/6): ").strip()

if choice in ['1', '6']:
    mermaid_content = generate_mermaid_graph(tables)
    with open('architecture_mermaid.md', 'w', encoding='utf-8') as f:
        f.write("# Architecture des données\n\n")
        f.write(mermaid_content)
    print("✅ Fichier 'architecture_mermaid.md' généré")

if choice in ['2', '6']:
    structured_data = generate_structured_json()
    with open('architecture_complete.json', 'w', encoding='utf-8') as f:
        json.dump(structured_data, f, indent=2, ensure_ascii=False)
    print("✅ Fichier 'architecture_complete.json' généré")

if choice in ['3', '6']:
    with open('tables_colonnes.csv', 'w', encoding='utf-8') as f:
        f.write("Table;Nom Technique;Nom Affiché;Avec Liste de Choix;Références\n")
        for table, cols in tables.items():
            for tech_name, display_name in cols.items():
                has_options = "Oui" if f"{table}.{tech_name}" in option_sets_by_column else "Non"
                references = ""
                option_key = f"{table}.{tech_name}"
                if option_key in option_set_references:
                    refs = option_set_references[option_key]
                    references = "|".join([f"{ref['entity']}.{ref['column']}" for ref in refs])
                f.write(f"{table};{tech_name};{display_name};{has_options};{references}\n")
    print("✅ Fichier 'tables_colonnes.csv' généré")

if choice in ['4', '6']:
    generate_drawio_complete(tables, option_sets_by_column, option_set_references)

if choice in ['5', '6']:
    generate_html_export(tables, option_sets_by_column, option_set_references)

print("\n🎉 Extraction terminée !")
# Out:
# === LISTE DES TABLES AVEC COLONNES ET LISTES DE CHOIX ===
#
# Table: Cuves (42 colonnes)
#   cr446_ProgAval → ProgAval
#   cr446_affectation_cuve_cr446_cuve → Affectations
#   cr446_affectee → % Affectée
#   cr446_choix1percent → % Choix 1
#   cr446_choix2percent → % Choix 2
#   cr446_choix3percent → % Choix 3
#   cr446_commentaire_Cuve_cr446_cuve → Commentaires
#   cr446_commentairecuve → Commentaire
#   cr446_cqfr_Cuve_cr446_cuve → CQFR
#   cr446_cuve_AsyncOperations → Tâches système
#   cr446_cuve_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_cuve_DuplicateBaseRecord → Enregistrements dupliqués (cr446_cuve_DuplicateBaseRecord)
#   cr446_cuve_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_cuve_DuplicateMatchingRecord)
#   cr446_cuve_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_cuve_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_cuve_ProcessSession → Sessions de traitement
#   cr446_cuve_SyncErrors → Erreurs de synchronisation
#   cr446_cuveid → Cuve
#   cr446_dateetape → Date Etape
#   cr446_defaut_Cuve_cr446_cuve → Défauts
#   cr446_espece → Espèce
#     📋 Liste de choix (5 valeurs):
#       113790000 → Alligator
#       113790001 → Niloticus
#       113790002 → Porosus
#       967350001 → Iguane
#       967350002 → Java
#     🔗 Référencé par:
#       → Cuves.cr446_espece
#       → Programmes.cr446_espece
#       → Affectations.cr446_espece
#       → Programmes Aval.cr446_espece
#       → CQFR.cr446_espece
#   cr446_essai_Cuve_cr446_cuve → Essais
#   cr446_etape → Etape
#   cr446_etapetri → EtapeTri
#   cr446_numero → Numéro
#   cr446_poids → Poids
#   cr446_poidstxt → PoidsTxt
#   cr446_priorite → Priorité
#     📋 Liste de choix (5 valeurs):
#       113790000 → Basse
#       113790001 → Moyenne
#       113790002 → Elevée
#       113790003 → Urgente
#       113790004 → Bloquée
#     🔗 Référencé par:
#       → Cuves.cr446_priorite
#   cr446_programme_Cuve_cr446_cuve → Programmes Amont
#   cr446_qtyaffectee → Qty Affectée
#   cr446_qtychoix1 → Qty Choix 1
#   cr446_qtychoix2 → Qty Choix 2
#   cr446_qtychoix3 → Qty Choix 3
#   cr446_quantite → Quantité
#   cr446_quantitetxt → QuantitéTxt
#   cr446_taille → Taille
#     📋 Liste de choix (9 valeurs):
#       1 → 19-
#       2 → 20-24
#       3 → 25-29
#       4 → 30-34
#       5 → 35-39
#       6 → 40-44
#       7 → 45-49
#       8 → 50-54
#       9 → 55-59
#     🔗 Référencé par:
#       → Cuves.cr446_taille
#       → Programmes.cr446_taille
#   cr446_tannage → Tannage
#     📋 Liste de choix (9 valeurs):
#       113790000 → Barolo
#       113790001 → Chantilly
#       113790002 → Classique
#       113790003 → Externe
#       113790004 → Himalaya
#       113790005 → Himalaya SCSB
#       113790006 → Jungle
#       113790007 → Sans Bisphenol
#       113790008 → Sans Chrome
#     🔗 Référencé par:
#       → Cuves.cr446_tannage
#       → Programmes.cr446_tannage
#   smallapp_etat → Etat
#   smallapp_familleespece → Famille Espèce
#     📋 Liste de choix (2 valeurs):
#       579940000 → Crocodile
#       579940001 → Lézard
#     🔗 Référencé par:
#       → Cuves.smallapp_familleespece
#       → Programmes.smallapp_familleespece
#       → Essais.smallapp_familleespece
#       → Programmes Aval.smallapp_familleespece
#       → Lots Achat.cr446_familleespece
#       → Lots Achat Taille.cr446_familleespece
#       → CQFR.smallapp_familleespece
#       → Cuves Lézard.smallapp_famille
#   smallapp_foulon → Foulon Rivière
#     📋 Liste de choix (14 valeurs):
#       579940000 → PT1
#       579940001 → PT2
#       579940002 → PT3
#       579940003 → PR1
#       579940004 → PR2
#       579940005 → PR3
#       579940006 → GT1
#       579940007 → GT2
#       579940008 → GT3
#       579940009 → GR1
#       579940010 → GR2
#       967350001 → NA
#       967350002 → ND
#       967350003 → Autres foulons teinture
#     🔗 Référencé par:
#       → Cuves.smallapp_foulon
#       → Cuves.smallapp_foulonretannage
#       → Cuves.smallapp_foulontannage
#       → Cuves Lézard.smallapp_foulonretannage
#       → Cuves Lézard.smallapp_foulonriviere
#       → Cuves Lézard.smallapp_foulontannage
#   smallapp_foulonretannage → Foulon Retannage
#   smallapp_foulontannage → Foulon Tannage
#
# Table: Programmes (43 colonnes)
#   cr446_Cuve → Cuve
#   cr446_affectation_Programme_cr446_programme → Affectations
#   cr446_choix1 → Choix 1 %
#   cr446_choix1qty → Choix 1 Qty
#   cr446_choix2 → Choix 2 %
#   cr446_choix2qty → Choix 2 Qty
#   cr446_choix3 → Choix 3 %
#   cr446_choix3qty → Choix 3 Qty
#   cr446_codearticle → Code Article
#   cr446_commentaire_Programme_cr446_programme → Commentaires
#   cr446_commentaireprog → Commentaire
#   cr446_datecave → DateCAVE
#   cr446_datedder → DateDDER
#   cr446_datedegr → DateDEGR
#   cr446_datedery → DateDERY
#   cr446_datedmrg → DateDMRG
#   cr446_datemaer → DateMAER
#   cr446_datetann → DateTANN
#   cr446_datetri → DateTRI
#   cr446_decoupe → Découpe
#     📋 Liste de choix (2 valeurs):
#       113790000 → BC
#       113790001 → FC
#     🔗 Référencé par:
#       → Programmes.cr446_decoupe
#       → Programmes Aval.cr446_decoupe
#       → Peaux.smallapp_decoupe
#   cr446_defaut_Programme_cr446_programme → Défauts
#   cr446_espece → Espèce
#   cr446_essai_Programme_cr446_programme → Essais
#   cr446_etapetri → Etape TRI
#   cr446_numero → Numéro
#   cr446_opencours → Opération en cours
#     📋 Liste de choix (10 valeurs):
#       0 → 0 - Démarrage production
#       1 → 1 - Mise à eau (rivière)
#       2 → 2 - Tannage
#       3 → 3 - Retannage
#       4 → 4 - Cave
#       5 → 5 - Disponible dérayage
#       6 → 6 - Dérayage
#       7 → 7 - Dégraissage
#       8 → 8 - Cadrage
#       9 → 9 - Contrôle qualité
#     🔗 Référencé par:
#       → Programmes.cr446_opencours
#   cr446_poids → Poids
#   cr446_progid → ProgID
#   cr446_programme_AsyncOperations → Tâches système
#   cr446_programme_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_programme_DuplicateBaseRecord → Enregistrements dupliqués (cr446_programme_DuplicateBaseRecord)
#   cr446_programme_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_programme_DuplicateMatchingRecord)
#   cr446_programme_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_programme_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_programme_ProcessSession → Sessions de traitement
#   cr446_programme_SyncErrors → Erreurs de synchronisation
#   cr446_programmeid → Programme
#   cr446_quantite → Quantité
#   cr446_taille → Taille
#   cr446_tannage → Tannage
#   smallapp_etape → Etape
#   smallapp_familleespece → Famille Espèce
#   smallapp_tri → Tri
#     📋 Liste de choix (2 valeurs):
#       0 → No
#       1 → Yes
#     🔗 Référencé par:
#       → Programmes.smallapp_tri
#
# Table: Essais (30 colonnes)
#   cr446_Cuve → Cuve (Crocodile)
#   cr446_Emetteurvivoin → Emetteurvivoin
#   cr446_ProgAval → Programme (Aval)
#   cr446_Programme → Programme (Amont)
#   cr446_atelier → Atelier concerné
#   cr446_commentaireessai → Intitulé
#   cr446_description → Description
#   cr446_emetteur → Emetteur
#   cr446_essai_AsyncOperations → Tâches système
#   cr446_essai_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_essai_DuplicateBaseRecord → Enregistrements dupliqués (cr446_essai_DuplicateBaseRecord)
#   cr446_essai_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_essai_DuplicateMatchingRecord)
#   cr446_essai_FileAttachments → FileAttachments
#   cr446_essai_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_essai_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_essai_ProcessSession → Sessions de traitement
#   cr446_essai_SyncErrors → Erreurs de synchronisation
#   cr446_essaiid → Essai
#   cr446_numeroessai → Numéro Essai
#   cr446_photo → Photo
#   cr446_photoid → cr446_PhotoId
#   cr83b_Emetteuravecmail → Emetteur avec mail
#   cr83b_complementpiecesjointes → Complement pieces jointes
#   smallapp_AffectationLotCuve → Partie de sous-lot <> Cuve
#   smallapp_CuveLezard → Cuve (Lézard)
#   smallapp_LotAchat → Lot d'achat
#   smallapp_LotAchatTaille → Sous-lot d'achat
#   smallapp_atelier → Atelier
#     📋 Liste de choix (15 valeurs):
#       579940000 → Agrafage
#       579940001 → Cadrage
#       579940002 → Dégraissage
#       579940003 → Dérayage
#       579940004 → Finition
#       579940005 → Flanche
#       579940006 → Humide
#       579940007 → Lisse
#       579940008 → Magasin Croûte
#       579940009 → Palisson
#       579940010 → Parage
#       579940011 → Qualité
#       579940012 → R&D
#       579940013 → Teinture
#       579940014 → Tri Croûte
#     🔗 Référencé par:
#       → Essais.smallapp_atelier
#   smallapp_familleespece → Famille Espèce
#   smallapp_statutcloture → Statut clotûre
#     📋 Liste de choix (4 valeurs):
#       579940000 → Concluant
#       579940001 → Non Concluant
#       579940002 → Abandonné
#       579940003 → En cours
#     🔗 Référencé par:
#       → Essais.smallapp_statutcloture
#
# Table: Affectations (22 colonnes)
#   cr446_Cuve → Cuve (Crocodile)
#   cr446_ProgAval → Programme (Aval)
#   cr446_Programme → Programme (Amont)
#   cr446_affectation → Affectation (cr446_affectation)
#     📋 Liste de choix (5 valeurs):
#       113790000 → Commande
#       113790001 → Désignation
#       113790002 → Réservation
#       113790003 → Relance
#       113790004 → Recoupe
#     🔗 Référencé par:
#       → Affectations.cr446_affectation
#       → Affectations.smallapp_choixaffectation
#   cr446_affectation_AsyncOperations → Tâches système
#   cr446_affectation_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_affectation_DuplicateBaseRecord → Enregistrements dupliqués (cr446_affectation_DuplicateBaseRecord)
#   cr446_affectation_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_affectation_DuplicateMatchingRecord)
#   cr446_affectation_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_affectation_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_affectation_ProcessSession → Sessions de traitement
#   cr446_affectation_SyncErrors → Erreurs de synchronisation
#   cr446_affectationid → Affectation (cr446_affectationid)
#   cr446_espece → Espèce
#   cr446_numeroaffectation → Numéro Affectation
#   cr446_quantite → Quantité
#   cr446_secteurdactivite → Secteur d'activité
#     📋 Liste de choix (8 valeurs):
#       113790000 → Bijouterie
#       113790001 → Ceinture
#       113790002 → Chaussure
#       113790003 → Matière 2 Sac
#       113790004 → PAP Femme
#       113790005 → PAP Homme
#       113790006 → PM
#       113790007 → Sac
#     🔗 Référencé par:
#       → Affectations.cr446_secteurdactivite
#   smallapp_AffectationLotCuve → Partie de sous-lot <> Cuve
#   smallapp_CuveLezard → Cuve (Lézard)
#   smallapp_LotAchat → Lot d'achat
#   smallapp_LotAchatTaille → Sous-lot d'achat
#   smallapp_choixaffectation → Choix Affectation
#
# Table: Défauts (24 colonnes)
#   cr446_Cuve → Cuve (Crocodile)
#   cr446_ProgAval → Programme (Aval)
#   cr446_Programme → Programme (Amont)
#   cr446_codedefaut → Code défaut
#     📋 Liste de choix (11 valeurs):
#       579940001 → B bretelle
#       579940002 → C cicatrice
#       579940003 → DP dépigmentation
#       579940004 → EC ecaille
#       579940005 → EF effleuré
#       579940006 → G griffe
#       579940007 → GE grain éclaté
#       579940008 → P piqué
#       579940009 → PV peau vide
#       579940010 → T trou
#       579940011 → TO tâche orange
#     🔗 Référencé par:
#       → Défauts.cr446_codedefaut
#   cr446_commentairedefaut → Description
#   cr446_defaut_AsyncOperations → Tâches système
#   cr446_defaut_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_defaut_DuplicateBaseRecord → Enregistrements dupliqués (cr446_defaut_DuplicateBaseRecord)
#   cr446_defaut_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_defaut_DuplicateMatchingRecord)
#   cr446_defaut_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_defaut_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_defaut_ProcessSession → Sessions de traitement
#   cr446_defaut_SyncErrors → Erreurs de synchronisation
#   cr446_defautid → Défaut
#   cr446_intitule → Intitulé (cr446_intitule)
#   cr446_intituledefaut → Intitulé (cr446_intituledefaut)
#   cr446_numerodefaut → Numéro Défaut
#   cr446_photodefaut → Photo défaut
#   cr446_photodefautid → cr446_PhotoDefautId
#   cr83b_codedefautc → Code defaut C
#     📋 Liste de choix (22 valeurs):
#       967350000 → P pix
#       967350001 → S cicatrice
#       967350002 → Q double ecaille
#       967350003 → G parasite sangsue
#       967350004 → M frisée crispéé
#       967350005 → W wrinkle
#       967350006 → V tâche blanche
#       967350007 → C coupure
#       967350008 → D nombril
#       967350009 → 0 creux blanc
#       967350010 → K bas de fleur
#       967350011 → 1 cloque
#       967350012 → 2 manque cites
#       967350013 → 6 arrêt de poisson
#       967350014 → Y gale
#       967350015 → N trou
#       967350016 → 12 naissance ecaille
#       967350017 → 8 pli de rivière
#       967350018 → 86 moisissure
#       967350019 → J coupure dérayage
#       967350020 → O graisse, gras
#       967350021 → 4 cratère
#     🔗 Référencé par:
#       → Défauts.cr83b_codedefautc
#   smallapp_AffectationLotCuve → Partie de sous-lot <> Cuve
#   smallapp_CuveLezard → Cuve (Lézard)
#   smallapp_LotAchat → Lot d'achat
#   smallapp_LotAchatTaille → Sous-lot d'achat
#
# Table: Commentaires (21 colonnes)
#   cr446_Cuve → Cuve (Crocodile)
#   cr446_ProgAval → Programme (Aval)
#   cr446_Programme → Programme (Amont)
#   cr446_codecommentaire → Code Commentaire
#   cr446_commentaire_AsyncOperations → Tâches système
#   cr446_commentaire_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_commentaire_DuplicateBaseRecord → Enregistrements dupliqués (cr446_commentaire_DuplicateBaseRecord)
#   cr446_commentaire_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_commentaire_DuplicateMatchingRecord)
#   cr446_commentaire_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_commentaire_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_commentaire_ProcessSession → Sessions de traitement
#   cr446_commentaire_SyncErrors → Erreurs de synchronisation
#   cr446_commentaireid → Commentaire
#   cr446_image → Image
#   cr446_imageid → cr446_ImageId
#   cr446_texte → Texte
#   smallapp_AffectationLotCuve → Partie de sous-lot <> Cuve
#   smallapp_CuveLezard → Cuve (Lézard)
#   smallapp_LotAchat → Lot d'achat
#   smallapp_LotAchatTaille → Sous-lot d'achat
#   smallapp_type → Type
#     📋 Liste de choix (3 valeurs):
#       1 → Classique
#       2 → Qualité
#       3 → Process
#     🔗 Référencé par:
#       → Commentaires.smallapp_type
#
# Table: Programmes Aval (49 colonnes)
#   cr446_affectation_ProgAval_cr446_programmeaval → Affectations
#   cr446_casier → Casier
#     📋 Liste de choix (52 valeurs):
#       113790000 → A1
#       113790001 → A2
#       113790002 → A3
#       113790003 → A4
#       113790004 → A5
#       113790005 → B1
#       113790006 → B2
#       113790007 → B3
#       113790008 → B4
#       113790009 → B5
#       113790010 → C1
#       113790011 → C2
#       113790012 → C3
#       113790013 → C4
#       113790014 → C5
#       113790015 → D1
#       113790016 → D2
#       113790017 → D3
#       113790018 → D4
#       113790019 → D5
#       113790020 → E1
#       113790021 → E2
#       113790022 → E3
#       113790023 → E4
#       113790024 → E5
#       113790025 → F1
#       113790026 → F2
#       113790027 → F3
#       113790028 → F4
#       113790029 → F5
#       113790030 → G1
#       113790031 → G2
#       113790032 → G3
#       113790033 → G4
#       113790034 → G5
#       113790035 → H1
#       113790036 → H2
#       113790037 → H3
#       113790038 → H4
#       113790039 → H5
#       113790040 → I1
#       113790041 → I2
#       113790042 → I3
#       113790043 → I4
#       113790044 → I5
#       113790045 → Côté étagère A
#       113790046 → Côté étagère B
#       113790047 → Côté étagère C
#       113790048 → Chariot triage
#       113790049 → Chariot côté étagère A
#       113790050 → Derrière cadreuse 1 et 2
#       113790051 → Etagère tri
#     🔗 Référencé par:
#       → Programmes Aval.cr446_casier
#   cr446_cdvliee → CDV liée
#   cr446_clientlivre → Client Livré
#   cr446_codearticle → Code Article
#   cr446_codecoloris → Code Coloris
#   cr446_codeespece → Code Espèce
#   cr446_codeetape → Code étape
#   cr446_codefinition → Code Finition
#   cr446_commentaire_ProgAval_cr446_programmeaval → Commentaires
#   cr446_cqfr_ProgAval_cr446_programmeaval → CQFR
#   cr446_cuve_ProgAval_cr446_programmeaval → Cuves Croco
#   cr446_datecommande → Date Commande
#   cr446_dateengagement → Date Engagement
#   cr446_decoupe → Découpe
#   cr446_defaut_ProgAval_cr446_programmeaval → Défauts
#   cr446_designation → Désignation
#   cr446_espece → Espèce
#   cr446_essai_ProgAval_cr446_programmeaval → Essais
#   cr446_etape → Etape
#   cr446_etat → Etat
#   cr446_libellearticle → Libellé Article
#   cr446_libellecoloris → Libellé Coloris
#   cr446_libellefinition → Libellé Finition
#   cr446_master → Master
#   cr446_ncommandeclient → N° Commande Client
#   cr446_poids → Poids
#   cr446_progid → ProgID
#   cr446_programmeaval_AsyncOperations → Tâches système
#   cr446_programmeaval_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_programmeaval_DuplicateBaseRecord → Enregistrements dupliqués (cr446_programmeaval_DuplicateBaseRecord)
#   cr446_programmeaval_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_programmeaval_DuplicateMatchingRecord)
#   cr446_programmeaval_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_programmeaval_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_programmeaval_ProcessSession → Sessions de traitement
#   cr446_programmeaval_SyncErrors → Erreurs de synchronisation
#   cr446_programmeavalid → Programme Aval
#   cr446_pxaaffecter → Px à affecter
#   cr446_pxnecessaires → Px nécessaires
#   cr446_pxrestantes → Px restantes
#   cr446_referencehermes → Référence Hermès
#   cr446_relance → Relance
#   cr446_resa → Résa
#     📋 Liste de choix (2 valeurs):
#       0 → No
#       1 → Yes
#     🔗 Référencé par:
#       → Programmes Aval.cr446_resa
#   cr446_taillemax → Taille Max
#   cr446_taillemin → Taille min
#   cr446_typeof → Type OF
#   smallapp_casiercheck → Casier Check
#   smallapp_datecasier → Date Casier
#   smallapp_familleespece → Famille Espèce
#
# Table: Lots Achat (31 colonnes)
#   cr446_familleespece → Famille Espèce
#   cr446_quantitechoix1bc → Quantité Choix 1 BC
#   cr446_quantitechoix2bc → Quantité Choix 2 BC
#   cr446_quantitechoix3bc → Quantité Choix 3 BC
#   smallapp_affectationlotcuve_LotAchat_smallapp_lotachat → Affectation Lot-Cuves
#   smallapp_cr446_affectation_LotAchat_smallapp_lotachat → Affectations
#   smallapp_cr446_commentaire_LotAchat_smallapp_lotachat → Commentaires
#   smallapp_cr446_defaut_LotAchat_smallapp_lotachat → Défauts
#   smallapp_cr446_essai_LotAchat_smallapp_lotachat → Essais
#   smallapp_espece → Espèce
#     📋 Liste de choix (3 valeurs):
#       579940000 → Varanus Niloticus
#       579940001 → Varanus Salvatore SD
#       579940002 → Varanus Salvatore VN
#     🔗 Référencé par:
#       → Lots Achat.smallapp_espece
#       → Lots Achat Taille.cr446_espece
#       → Affectations Lot-Cuve.cr446_espece
#       → Cuves Lézard.smallapp_espece
#   smallapp_identifiant → Identifiant
#   smallapp_lotachat_AsyncOperations → Tâches système
#   smallapp_lotachat_BulkDeleteFailures → Échecs des suppressions en bloc
#   smallapp_lotachat_DuplicateBaseRecord → Enregistrements dupliqués (smallapp_lotachat_DuplicateBaseRecord)
#   smallapp_lotachat_DuplicateMatchingRecord → Enregistrements dupliqués (smallapp_lotachat_DuplicateMatchingRecord)
#   smallapp_lotachat_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   smallapp_lotachat_PrincipalObjectAttributeAccesses → Partage de champ
#   smallapp_lotachat_ProcessSession → Sessions de traitement
#   smallapp_lotachat_SyncErrors → Erreurs de synchronisation
#   smallapp_lotachatid → Lot Achat
#   smallapp_lotachattaille_LotAchat_smallapp_lotachat → Lots Achat Taille
#   smallapp_numerolot → Numéro Lot
#   smallapp_origine → Origine
#     📋 Liste de choix (5 valeurs):
#       579940000 → ABI
#       579940001 → BIZ
#       579940002 → VER
#       579940003 → VV
#       579940004 → YOU
#     🔗 Référencé par:
#       → Lots Achat.smallapp_origine
#       → Lots Achat Taille.cr446_origine
#   smallapp_peaux_LotAchat_smallapp_lotachat → Peaux
#   smallapp_quantitebc → Quantité BC
#   smallapp_quantitechoix1 → Quantité Choix 1 FC
#   smallapp_quantitechoix2 → Quantité Choix 2 FC
#   smallapp_quantitechoix3 → Quantité Choix 3 FC
#   smallapp_quantitefc → Quantité FC
#   smallapp_quantiterecue → Quantité Reçue
#   smallapp_quantiterejetee → Quantité Rejetée
#
# Table: Lots Achat Taille (30 colonnes)
#   cr446_espece → Espèce
#   cr446_familleespece → Famille Espèce
#   cr446_origine → Origine
#   cr446_quantitechoix1bc → Quantité Choix 1 BC
#   cr446_quantitechoix2bc → Quantité Choix 2 BC
#   cr446_quantitechoix3bc → Quantité Choix 3 BC
#   cr446_quantiterejetee → Quantité Rejetée
#   smallapp_LotAchat → Lot Achat
#   smallapp_affectationlotcuve_LotAchatTaille_smallapp_lotachattaille → Affectation Lot-Cuves
#   smallapp_cr446_affectation_LotAchatTaille_smallapp_lotachattaille → Affectations
#   smallapp_cr446_commentaire_LotAchatTaille_smallapp_lotachattaille → Commentaires
#   smallapp_cr446_defaut_LotAchatTaille_smallapp_lotachattaille → Défauts
#   smallapp_cr446_essai_LotAchatTaille_smallapp_lotachattaille → Essais
#   smallapp_identifiant → Identifiant
#   smallapp_lotachattaille_AsyncOperations → Tâches système
#   smallapp_lotachattaille_BulkDeleteFailures → Échecs des suppressions en bloc
#   smallapp_lotachattaille_DuplicateBaseRecord → Enregistrements dupliqués (smallapp_lotachattaille_DuplicateBaseRecord)
#   smallapp_lotachattaille_DuplicateMatchingRecord → Enregistrements dupliqués (smallapp_lotachattaille_DuplicateMatchingRecord)
#   smallapp_lotachattaille_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   smallapp_lotachattaille_PrincipalObjectAttributeAccesses → Partage de champ
#   smallapp_lotachattaille_ProcessSession → Sessions de traitement
#   smallapp_lotachattaille_SyncErrors → Erreurs de synchronisation
#   smallapp_lotachattailleid → Lot Achat Taille
#   smallapp_peaux_LotAchatTaille_smallapp_lotachattaille → Peaux
#   smallapp_quantitebc → Quantité BC
#   smallapp_quantitechoix1 → Quantité Choix 1 FC
#   smallapp_quantitechoix2 → Quantité Choix 2 FC
#   smallapp_quantitechoix3 → Quantité Choix 3 FC
#   smallapp_quantitefc → Quantité FC
#   smallapp_taille → Taille
#     📋 Liste de choix (22 valeurs):
#       579940000 → 19-
#       579940001 → 20
#       579940002 → 21
#       579940003 → 22
#       579940004 → 23
#       579940005 → 24
#       579940006 → 25
#       579940007 → 26
#       579940008 → 27
#       579940009 → 28
#       579940010 → 29
#       579940011 → 30
#       579940012 → 31
#       579940013 → 32
#       579940014 → 33
#       579940015 → 34
#       579940016 → 35
#       579940017 → 36
#       579940018 → 37
#       579940019 → 38
#       579940020 → 39
#       579940021 → 40+
#     🔗 Référencé par:
#       → Lots Achat Taille.smallapp_taille
#       → Peaux.smallapp_taille
#       → Peaux.smallapp_taillecroute
#
# Table: Peaux (22 colonnes)
#   smallapp_AffectationLotCuve → Affectation Lot-Cuve
#   smallapp_Cuve → Cuve Lézard
#   smallapp_LotAchat → Lot Achat
#   smallapp_LotAchatTaille → Lot Achat Taille
#   smallapp_choix → Choix
#   smallapp_choixcroute → Choix Croute
#   smallapp_choixhermes → Choix Hermès
#   smallapp_decoupe → Découpe
#   smallapp_emplacementcroute → Emplacement Croute
#   smallapp_modelecroute → Modèle Croute
#     📋 Liste de choix (56 valeurs):
#       579940000 → AZAP INTEGRAL
#       579940001 → BANGLE OLYMPE
#       579940002 → BEARN COMPACT
#       579940003 → BIRKIN 25
#       579940004 → BIRKIN 30
#       579940005 → BIRKIN SELLIER 20
#       579940006 → BIRKIN SELLIER 20 SERTI
#       579940007 → BK 25 TOUCH
#       579940008 → BOLIDE MINI 1923
#       579940009 → BOLIDE TOUCH
#       579940010 → BOUCLE OREILLES OLYMPE
#       579940011 → CALVI
#       579940012 → CALVI DUO
#       579940013 → CHAINE D'ANCRE COMPACT
#       579940014 → COFFRET AMALTHEE PM
#       579940015 → COLLIER DE CHIEN
#       579940016 → COLLIER DE CHIEN 24
#       579940017 → CONSTANCE 1-24
#       579940018 → CONSTANCE III MINI
#       579940019 → CONSTANCE III MINI MIROIR
#       579940020 → CONSTANCE MICRO
#       579940021 → CONSTANCE SLIM COMPACT
#       579940022 → CONSTANCE TO GO
#       579940023 → ETUI MONTRE GM
#       579940024 → ETUI MONTRE PM
#       579940025 → H CHAUSSURE GLAMOUR FULL
#       579940026 → HACABOX
#       579940027 → HERMES GANTS
#       579940028 → HERMES MINUIT AU FAUBOURG 20
#       579940029 → ILIADE PORTE-CARTES
#       579940030 → JIGE ELAN TOUCH
#       579940031 → JOY 105, FULL MODELE
#       579940032 → KELLY DANSE II
#       579940033 → KELLY DEPECHES 25
#       579940034 → KELLY DOUBLE TOUR
#       579940035 → KELLY ELAN
#       579940036 → KELLY FESTIVAL
#       579940037 → KELLY II SELLIER 25
#       579940038 → KELLY II SELLIER 25 KELLYOPTIC
#       579940039 → KELLY II SELLIER 28
#       579940040 → KELLY II SELLIER MINI
#       579940041 → KELLY II SELLIER MINI TOUCH
#       579940042 → KELLY MESSENGER PM
#       579940043 → KELLY MINI
#       579940044 → KELLY TO GO
#       579940045 → MAH-JONG
#       579940046 → OASIS FEMME H PUNTINA FILETTO
#       579940047 → PICOTIN LOCL MICRO
#       579940048 → POCHETTE KELLY MINI
#       579940049 → ROULIS MINI
#       579940050 → ROULIS SLIM COMPACT
#       579940051 → SAC A DEPECHES 21
#       579940052 → SAC A DEPECHES 24
#       579940053 → TOUCH 3 KELLY RET 25
#       579940054 → TWIST PM
#       579940055 → VERROU CHAINE MINI
#     🔗 Référencé par:
#       → Peaux.smallapp_modelecroute
#       → CQFR.smallapp_modele
#   smallapp_peaux_AsyncOperations → Tâches système
#   smallapp_peaux_BulkDeleteFailures → Échecs des suppressions en bloc
#   smallapp_peaux_DuplicateBaseRecord → Enregistrements dupliqués (smallapp_peaux_DuplicateBaseRecord)
#   smallapp_peaux_DuplicateMatchingRecord → Enregistrements dupliqués (smallapp_peaux_DuplicateMatchingRecord)
#   smallapp_peaux_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   smallapp_peaux_PrincipalObjectAttributeAccesses → Partage de champ
#   smallapp_peaux_ProcessSession → Sessions de traitement
#   smallapp_peaux_SyncErrors → Erreurs de synchronisation
#   smallapp_peauxid → Peaux
#   smallapp_rfid → RFID
#   smallapp_taille → Taille
#   smallapp_taillecroute → Taille Croute
#
# Table: CQFR (38 colonnes)
#   cr446_Cuve → Cuve (Crocodile)
#   cr446_ProgAval → Programme (Aval)
#   cr446_brillance → Brillance %
#   cr446_commentairequalite → Commentaire Qualité
#   cr446_cqfr_AsyncOperations → Tâches système
#   cr446_cqfr_BulkDeleteFailures → Échecs des suppressions en bloc
#   cr446_cqfr_DuplicateBaseRecord → Enregistrements dupliqués (cr446_cqfr_DuplicateBaseRecord)
#   cr446_cqfr_DuplicateMatchingRecord → Enregistrements dupliqués (cr446_cqfr_DuplicateMatchingRecord)
#   cr446_cqfr_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   cr446_cqfr_PrincipalObjectAttributeAccesses → Partage de champ
#   cr446_cqfr_ProcessSession → Sessions de traitement
#   cr446_cqfr_SyncErrors → Erreurs de synchronisation
#   cr446_cqfrid → CQFR
#   cr446_espece → Espèce
#   cr446_homogeneite → Homogénéité %
#   cr446_libellearticle → Libellé Article
#   cr446_libellecoloris → Libellé Coloris
#   cr446_libellefinition → Libellé Finition
#   cr446_numero → Numero
#   cr446_quantite → Quantité
#   cr446_souplesse → Souplesse %
#   cr446_spectro → Spectro
#   cr446_taillemax → Taille Max
#   cr446_taillemin → Taille Min
#   cr446_touche → Touché %
#   smallapp_familleespece → Famille Espèce
#   smallapp_modele → Modèle
#   smallapp_quantitelivree → Quantité livrée
#   smallapp_quantiterebutrejet → Quantité rebut/rejet
#   smallapp_resultatveslichumidecuir → Résultat Veslic Humide Cuir
#     📋 Liste de choix (12 valeurs):
#       579940000 → 0
#       579940001 → 0-1
#       579940002 → 1
#       579940003 → 1-2
#       579940004 → 2
#       579940005 → 2-3
#       579940006 → 3
#       579940007 → 3-4
#       579940008 → 4
#       579940009 → 4-5
#       579940010 → 5
#       579940011 → N/A
#     🔗 Référencé par:
#       → CQFR.smallapp_resultatveslichumidecuir
#       → CQFR.smallapp_resultatveslichumidefeutre
#       → CQFR.smallapp_resultatveslicseccuir
#       → CQFR.smallapp_resultatveslicsecfeutre
#       → CQFR.smallapp_testpvc
#       → CQFR.smallapp_testscotch
#       → CQFR.smallapp_uv12h
#       → CQFR.smallapp_uv24h
#       → CQFR.smallapp_uv6h
#   smallapp_resultatveslichumidefeutre → Résultat Veslic Humide Feutre
#   smallapp_resultatveslicseccuir → Résultat Veslic Sec Cuir
#   smallapp_resultatveslicsecfeutre → Résultat Veslic Sec Feutre
#   smallapp_testpvc → Test PVC
#   smallapp_testscotch → Test Scotch
#   smallapp_uv12h → UV12h
#   smallapp_uv24h → UV24h
#   smallapp_uv6h → UV6H
#
# Table: Affectations Lot-Cuve (25 colonnes)
#   cr446_espece → Espèce
#   smallapp_CuveLezard → Cuve Lézard
#   smallapp_LotAchat → Lot Achat
#   smallapp_LotAchatTaille → Lot Achat Taille
#   smallapp_affectationlotcuve_AsyncOperations → Tâches système
#   smallapp_affectationlotcuve_BulkDeleteFailures → Échecs des suppressions en bloc
#   smallapp_affectationlotcuve_DuplicateBaseRecord → Enregistrements dupliqués (smallapp_affectationlotcuve_DuplicateBaseRecord)
#   smallapp_affectationlotcuve_DuplicateMatchingRecord → Enregistrements dupliqués (smallapp_affectationlotcuve_DuplicateMatchingRecord)
#   smallapp_affectationlotcuve_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   smallapp_affectationlotcuve_PrincipalObjectAttributeAccesses → Partage de champ
#   smallapp_affectationlotcuve_ProcessSession → Sessions de traitement
#   smallapp_affectationlotcuve_SyncErrors → Erreurs de synchronisation
#   smallapp_affectationlotcuveid → Affectation Lot-Cuve
#   smallapp_cr446_affectation_AffectationLotCuve_smallapp_affectationlotcuve → Affectations
#   smallapp_cr446_commentaire_AffectationLotCuve_smallapp_affectationlotcuve → Commentaires
#   smallapp_cr446_defaut_AffectationLotCuve_smallapp_affectationlotcuve → Défauts
#   smallapp_cr446_essai_AffectationLotCuve_smallapp_affectationlotcuve → Essais
#   smallapp_identifiant → Identifiant
#   smallapp_peaux_AffectationLotCuve_smallapp_affectationlotcuve → Peaux
#   smallapp_quantitebc → Quantité BC
#   smallapp_quantitechoix1 → Quantité Choix 1
#   smallapp_quantitechoix2 → Quantité Choix 2
#   smallapp_quantitechoix3 → Quantité Choix 3
#   smallapp_quantitefc → Quantité FC
#   smallapp_quantitetotale → Quantité Totale
#
# Table: Cuves Lézard (33 colonnes)
#   smallapp_affectationlotcuve_CuveLezard_smallapp_cuvelezard → Affectation Lot-Cuves
#   smallapp_cr446_affectation_CuveLezard_smallapp_cuvelezard → Affectations
#   smallapp_cr446_commentaire_CuveLezard_smallapp_cuvelezard → Commentaires
#   smallapp_cr446_defaut_CuveLezard_smallapp_cuvelezard → Défauts
#   smallapp_cr446_essai_CuveLezard_smallapp_cuvelezard → Essais
#   smallapp_cuvelezard_AsyncOperations → Tâches système
#   smallapp_cuvelezard_BulkDeleteFailures → Échecs des suppressions en bloc
#   smallapp_cuvelezard_DuplicateBaseRecord → Enregistrements dupliqués (smallapp_cuvelezard_DuplicateBaseRecord)
#   smallapp_cuvelezard_DuplicateMatchingRecord → Enregistrements dupliqués (smallapp_cuvelezard_DuplicateMatchingRecord)
#   smallapp_cuvelezard_MailboxTrackingFolders → Dossiers de suivi automatique de la boîte aux lettres
#   smallapp_cuvelezard_PrincipalObjectAttributeAccesses → Partage de champ
#   smallapp_cuvelezard_ProcessSession → Sessions de traitement
#   smallapp_cuvelezard_SyncErrors → Erreurs de synchronisation
#   smallapp_cuvelezardid → Cuve Lézard
#   smallapp_datemae → Date MAE
#   smallapp_datetri → Date Tri
#   smallapp_espece → Espèce
#   smallapp_etape → Etape
#   smallapp_etapeauto → Etape Auto
#   smallapp_etat → Etat
#   smallapp_famille → Famille
#   smallapp_foulonretannage → Foulon Retannage
#   smallapp_foulonriviere → Foulon Rivière
#   smallapp_foulontannage → Foulon Tannage
#   smallapp_numero → Numéro
#   smallapp_peaux_Cuve_smallapp_cuvelezard → Peaux
#   smallapp_poids → Poids
#   smallapp_quantitebc → Quantité BC
#   smallapp_quantitechoix1 → Quantité Choix 1
#   smallapp_quantitechoix2 → Quantité Choix 2
#   smallapp_quantitechoix3 → Quantité Choix 3
#   smallapp_quantitefc → Quantité FC
#   smallapp_quantitemae → Quantité MAE
#
# === OPTIONS D'EXPORT ===
# 1. Mermaid (pour diagramme ER)
# 2. JSON structuré (complet)
# 3. CSV des tables et colonnes
# 4. XML Draw.io
# 5. HTML (complet avec références)
# 6. Tous les formats
# ✅ Fichier 'architecture_complete.drawio' généré
# Nombre de tables:  13
# Nombre total de colonnes:  410
# Nombre de tables de choix générées:  81
#
# 🎉 Extraction terminée !
